# %% [markdown]
# # PREPARACION DE DATOS

# %% [markdown]
# En esta fase vamos a crear nuevas variables o transformar las existentes para poder dar mejor respuesta a nuestro objetivo.

# %% [markdown]
# ## SET UP

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import sqlalchemy as sa
import math
import sqlite3

#Automcompletar rápido
# %config IPCompleter.greedy=True

pd.options.display.max_columns = None
pd.options.display.max_rows = 400

# %% [markdown]
# ## CARGA DE DATOS

# %%
from sqlalchemy import text

# Ruta del proyecto
ruta_proyecto = 'C:/Users/Oscar/OneDrive - FM4/Escritorio/EVOLVE/Data Science/Proyecto-Master-DataScience-Evolve-OscarFraile'

# Nombre del fichero de datos
nombre_fichero_datos = 'airbnb2025.db'

# Ruta completa
ruta_completa = ruta_proyecto + '/02_Datos/01_Originales/' + nombre_fichero_datos

# Conexión sqlite3
conn_lite = sqlite3.connect(ruta_completa)

cat = pd.read_sql('SELECT * FROM cat', conn_lite).drop(columns='index')
num = pd.read_sql('SELECT * FROM num', conn_lite).drop(columns='index')

df = pd.merge(cat, num, how='inner', on='id')

# %%
cursor = conn_lite.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table'")
tablas = cursor.fetchall()
tablas
# Out:
# [('listings',),
#  ('listings_det',),
#  ('calendar',),
#  ('neigh',),
#  ('target',),
#  ('id_df',),
#  ('precio_total_df',),
#  ('extras_df',),
#  ('cat',),
#  ('num',),
#  ('precio_m2',),
#  ('df_preparado',)]

# %%
ruta_db = ruta_proyecto + '/02_Datos/01_Originales/airbnb2025.db' 

conn_lite = sqlite3.connect(ruta_db)
print(pd.read_sql('SELECT COUNT(*) FROM cat', conn_lite))
# Out:
#    COUNT(*)
# 0     25873

# %%
df
# Out:
#                         id                                            name  \
# 0                    21853                            Bright and airy room
# 1                    30320                     Great Vacational Apartments
# 2                    30959                 Beautiful loft in Madrid Center
# 3                    40916                 Holiday Apartment Madrid Center
# 4                    62423    MAGIC ARTISTIC HOUSE IN THE CENTER OF MADRID
# ...                    ...                                             ...
# 25868  1308811268356474614                            Habitación tranquila
# 25869  1308816654087147793            Vive Madrid Río con Confort y Estilo
# 25870  1308818613904246041                 Alquilo habitación por 15 días.
# 25871  1308842708819314249  Estudio luminoso y renovado junto a Madrid Río
# 25872  1308864880309321118                 Precioso y Moderno en el Centro
#
#        host_response_time host_is_superhost                host_verifications  \
# 0             no response                 f                ['email', 'phone']
# 1             no response                 f                ['email', 'phone']
# 2             no response                 f                ['email', 'phone']
# 3             no response                 f                ['email', 'phone']
# 4          within an hour                 f                ['email', 'phone']
# ...                   ...               ...                               ...
# 25868      within an hour                 f                         ['phone']
# 25869  within a few hours                 f                ['email', 'phone']
# 25870         no response                 f                ['email', 'phone']
# 25871  within a few hours                 f                ['email', 'phone']
# 25872      within an hour                 f  ['email', 'phone', 'work_email']
#
#       host_has_profile_pic host_identity_verified neighbourhood_cleansed  \
# 0                        t                      t               Cármenes
# 1                        t                      f                    Sol
# 2                        t                      f            Embajadores
# 3                        t                      f            Universidad
# 4                        t                      t               Justicia
# ...                    ...                    ...                    ...
# 25868                    t                      t                 Ventas
# 25869                    t                      t       Puerta del Angel
# 25870                    t                      t                Palacio
# 25871                    t                      t       Puerta del Angel
# 25872                    t                      t                 Atocha
#
#                      property_type        room_type  \
# 0      Private room in rental unit     Private room
# 1               Entire rental unit  Entire home/apt
# 2                      Entire loft  Entire home/apt
# 3               Entire rental unit  Entire home/apt
# 4      Private room in rental unit     Private room
# ...                            ...              ...
# 25868  Private room in rental unit     Private room
# 25869           Entire rental unit  Entire home/apt
# 25870  Private room in rental unit     Private room
# 25871           Entire rental unit  Entire home/apt
# 25872           Entire rental unit  Entire home/apt
#
#                                                amenities has_availability  \
# 0      ["First aid kit", "Wifi", "Kitchen", "Essentia...              yes
# 1      ["Heating", "Wifi", "TV with standard cable", ...               no
# 2      ["Breakfast", "Heating", "Wifi", "Smoking allo...               no
# 3      ["Heating", "Wifi", "Pets allowed", "Kitchen",...               no
# 4      ["Books and reading material", "First aid kit"...              yes
# ...                                                  ...              ...
# 25868                                     ["Wifi", "TV"]              yes
# 25869  ["Wifi", "Kitchen", "Hot water", "Microwave", ...              yes
# 25870                          ["Wifi", "Kitchen", "TV"]              yes
# 25871  ["Wifi", "Kitchen", "Hot water", "Microwave", ...              yes
# 25872  ["Paid parking on premises", "Exercise equipme...              yes
#
#       license instant_bookable neighbourhood_group    host_id  \
# 0          no                f              Latina      83531
# 1          no                f              Centro     130907
# 2          no                f              Centro     132883
# 3          no                f              Centro     130907
# 4          no                f              Centro     303845
# ...       ...              ...                 ...        ...
# 25868      no                f       Ciudad Lineal  548687839
# 25869      no                t              Latina  251333188
# 25870      no                f              Centro  118339834
# 25871      no                t              Latina  251333188
# 25872      no                f          Arganzuela   91095901
#
#                        host_since  host_response_rate  host_acceptance_rate  \
# 0      2010-02-21 00:00:00.000000                 0.0                   0.0
# 1      2010-05-24 00:00:00.000000                 0.0                  93.0
# 2      2010-05-26 00:00:00.000000                 0.0                  88.0
# 3      2010-05-24 00:00:00.000000                 0.0                  89.0
# 4      2010-11-29 00:00:00.000000               100.0                 100.0
# ...                           ...                 ...                   ...
# 25868  2023-11-29 00:00:00.000000               100.0                  69.0
# 25869  2019-03-26 00:00:00.000000               100.0                  67.0
# 25870  2017-02-27 00:00:00.000000                 0.0                  90.0
# 25871  2019-03-26 00:00:00.000000               100.0                  67.0
# 25872  2016-08-21 00:00:00.000000               100.0                 100.0
#
#        host_listings_count  host_total_listings_count   latitude  longitude  \
# 0                      2.0                        2.0  40.403810  -3.741300
# 1                      3.0                        6.0  40.414760  -3.704180
# 2                      1.0                        4.0  40.412590  -3.701050
# 3                      3.0                        6.0  40.422470  -3.705770
# 4                      3.0                        3.0  40.418840  -3.696550
# ...                    ...                        ...        ...        ...
# 25868                  1.0                        2.0  40.429945  -3.653817
# 25869                163.0                      234.0  40.413716  -3.724050
# 25870                  1.0                        1.0  40.413342  -3.709019
# 25871                163.0                      234.0  40.412371  -3.724235
# 25872                  9.0                       12.0  40.397124  -3.679787
#
#        accommodates  bathrooms  bedrooms  beds  price  minimum_nights  \
# 0                 1        1.0       1.0   1.0     31               4
# 1                 2        1.0       1.0   1.0    149               5
# 2                 2        1.0       1.0   1.0     92               3
# 3                 3        1.0       1.0   2.0    124               5
# 4                 4        1.5       1.0   2.0     69               1
# ...             ...        ...       ...   ...    ...             ...
# 25868             2        1.0       1.0   1.0     85               5
# 25869             4        1.0       1.0   2.0    258               1
# 25870             1        1.0       1.0   1.0     20              15
# 25871             2        1.0       1.0   2.0    258               1
# 25872             2        1.0       1.0   1.0    161               7
#
#        maximum_nights  availability_30  availability_60  availability_90  \
# 0                  40                0                0                0
# 1                 180                0                0                0
# 2                 730                0                0                0
# 3                 180                0                0                0
# 4                  30               13               37               59
# ...               ...              ...              ...              ...
# 25868              15               30               60               90
# 25869             365               15               45               75
# 25870              16               29               59               89
# 25871             365               13               43               73
# 25872             300               30               60               90
#
#        availability_365  number_of_reviews  number_of_reviews_ltm  \
# 0                   144                 33                      0
# 1                     0                172                      0
# 2                     0                  8                      0
# 3                     0                 49                      0
# 4                   332                219                     44
# ...                 ...                ...                    ...
# 25868               365                  0                      0
# 25869               350                  0                      0
# 25870               364                  0                      0
# 25871               348                  0                      0
# 25872                90                  0                      0
#
#        number_of_reviews_l30d                first_review  \
# 0                           0  2014-10-10 00:00:00.000000
# 1                           0  2010-07-06 00:00:00.000000
# 2                           0  2015-05-12 00:00:00.000000
# 3                           0  2010-11-01 00:00:00.000000
# 4                           3  2018-05-10 00:00:00.000000
# ...                       ...                         ...
# 25868                       0  2023-11-29 00:00:00.000000
# 25869                       0  2019-03-26 00:00:00.000000
# 25870                       0  2017-02-27 00:00:00.000000
# 25871                       0  2019-03-26 00:00:00.000000
# 25872                       0  2016-08-21 00:00:00.000000
#
#                       last_review  review_scores_rating  \
# 0      2018-07-15 00:00:00.000000                  4.58
# 1      2022-09-26 00:00:00.000000                  4.63
# 2      2017-05-30 00:00:00.000000                  4.38
# 3      2021-12-11 00:00:00.000000                  4.65
# 4      2024-11-24 00:00:00.000000                  4.64
# ...                           ...                   ...
# 25868  2023-11-29 00:00:00.000000                  0.00
# 25869  2019-03-26 00:00:00.000000                  0.00
# 25870  2017-02-27 00:00:00.000000                  0.00
# 25871  2019-03-26 00:00:00.000000                  0.00
# 25872  2016-08-21 00:00:00.000000                  0.00
#
#        review_scores_accuracy  review_scores_cleanliness  \
# 0                        4.72                       4.56
# 1                        4.71                       4.88
# 2                        4.14                       4.38
# 3                        4.69                       4.90
# 4                        4.78                       4.42
# ...                       ...                        ...
# 25868                    0.00                       0.00
# 25869                    0.00                       0.00
# 25870                    0.00                       0.00
# 25871                    0.00                       0.00
# 25872                    0.00                       0.00
#
#        review_scores_checkin  review_scores_communication  \
# 0                       4.75                         4.82
# 1                       4.82                         4.78
# 2                       4.63                         4.63
# 3                       4.85                         4.79
# 4                       4.79                         4.85
# ...                      ...                          ...
# 25868                   0.00                         0.00
# 25869                   0.00                         0.00
# 25870                   0.00                         0.00
# 25871                   0.00                         0.00
# 25872                   0.00                         0.00
#
#        review_scores_location  review_scores_value  \
# 0                        4.21                 4.67
# 1                        4.90                 4.69
# 2                        4.88                 4.25
# 3                        4.88                 4.55
# 4                        4.97                 4.58
# ...                       ...                  ...
# 25868                    0.00                 0.00
# 25869                    0.00                 0.00
# 25870                    0.00                 0.00
# 25871                    0.00                 0.00
# 25872                    0.00                 0.00
#
#        calculated_host_listings_count  \
# 0                                   2
# 1                                   3
# 2                                   1
# 3                                   3
# 4                                   3
# ...                               ...
# 25868                               1
# 25869                              19
# 25870                               1
# 25871                              19
# 25872                               6
#
#        calculated_host_listings_count_entire_homes  \
# 0                                                0
# 1                                                3
# 2                                                1
# 3                                                3
# 4                                                1
# ...                                            ...
# 25868                                            0
# 25869                                           19
# 25870                                            0
# 25871                                           19
# 25872                                            6
#
#        calculated_host_listings_count_private_rooms  \
# 0                                                 2
# 1                                                 0
# 2                                                 0
# 3                                                 0
# 4                                                 2
# ...                                             ...
# 25868                                             1
# 25869                                             0
# 25870                                             1
# 25871                                             0
# 25872                                             0
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month  \
# 0                                                0               0.27
# 1                                                0               0.98
# 2                                                0               0.07
# 3                                                0               0.29
# 4                                                0               2.73
# ...                                            ...                ...
# 25868                                            0               0.00
# 25869                                            0               0.00
# 25870                                            0               0.00
# 25871                                            0               0.00
# 25872                                            0               0.00
#
#        precio_m2
# 0           2772
# 1           6170
# 2           6170
# 3           6170
# 4           6170
# ...          ...
# 25868       3676
# 25869       2772
# 25870       6170
# 25871       2772
# 25872       4850
#
# [25873 rows x 52 columns]

# %% [markdown]
# ## PREPARACION DE VARIABLES

# %% [markdown]
# ### Creacion de kpis de palancas

# %% [markdown]
# Primero vamos a crear las variables de análisis, es decir las que habíamos identificado como los Kpis que usaremos en las palancas que influyen sobre el negocio.
#
# Habíamos dicho que eran 3:
#
# * precio por noche: esta ya la tenemos directamente en la variable price, pero vamos a revisarla para ver que la entendemos bien
# * ocupación: tenemos availability_365 pero hay que transformarla
# * precio del inmueble: esta tendremos que crearla con variables externas así que la dejamos para después

# %% [markdown]
# **Empezamos con el precio.**
#
# La documentación no aclara si el precio es por todo el inmueble, o si en el caso de que se alquile una habitación es por habitación.
#
# Es un dato clave para poder hacer la valoración de los potenciales ingresos de un inmueble.
#
# Vamos a intentar entenderlo analizando el precio medio por tipo de alquiler.
#
# Es importante filtrar por solo un distrito para no incluir el efecto "zona".
#
# Así que primero elegimos un distrito que tenga muchos datos.

# %%
df.neighbourhood_group.value_counts()
# Out:
# Centro                10495
# Salamanca              1768
# Chamberí               1678
# Tetuán                 1614
# Arganzuela             1402
# Carabanchel             984
# Ciudad Lineal           961
# Retiro                  961
# Chamartín               849
# Puente de Vallecas      806
# Latina                  695
# Moncloa                 691
# Usera                   608
# San Blas                592
# Hortaleza               518
# Fuencarral              386
# Villaverde              265
# Moratalaz               190
# Barajas                 185
# Villa de Vallecas       137
# Vicálvaro                88
# Name: neighbourhood_group, dtype: int64

# %%
df.loc[df.neighbourhood_group == 'Centro',:].groupby('room_type').price.mean()
# Out:
# room_type
# Entire home/apt    146.260896
# Private room        82.477619
# Shared room         67.485714
# Name: price, dtype: float64

# %%
df.loc[(df.neighbourhood_group == 'Centro')&(df.room_type == 'Shared room')].groupby(['room_type','beds']).price.count()
# Out:
# room_type    beds
# Shared room  0.0      3
#              1.0     35
#              2.0      4
#              3.0      3
#              4.0      7
#              6.0     11
#              8.0      6
#              12.0     1
# Name: price, dtype: int64

# %%
df.loc[df.neighbourhood_group == 'Centro'].groupby(['room_type','beds']).price.mean()
# Out:
# room_type        beds
# Entire home/apt  0.0     122.932203
#                  1.0     106.201364
#                  2.0     137.124126
#                  3.0     175.667707
#                  4.0     214.460102
#                  5.0     261.317460
#                  6.0     306.323529
#                  7.0     348.111111
#                  8.0     327.695652
#                  9.0     330.272727
#                  10.0    354.733333
#                  11.0    350.250000
#                  13.0    419.000000
#                  14.0    481.750000
#                  15.0    680.500000
#                  16.0    528.000000
#                  18.0    606.000000
# Private room     0.0      64.714286
#                  1.0      78.323799
#                  2.0     100.308594
#                  3.0     101.976744
#                  4.0     203.434783
#                  5.0      81.400000
#                  6.0      82.250000
#                  8.0      74.000000
#                  9.0     117.000000
#                  14.0    107.000000
#                  19.0     34.000000
# Shared room      0.0      35.333333
#                  1.0      70.885714
#                  2.0      87.000000
#                  3.0     307.666667
#                  4.0      30.857143
#                  6.0      29.636364
#                  8.0      31.166667
#                  12.0    137.000000
# Name: price, dtype: float64

# %% [markdown]
# Conclusión:
#
# * alquilar el apartamento tiene un precio medio de 158€
# * alquilar una habitación tiene un precio medio de 82€ privada o 67€ compartida
# * por tanto para calcular los "ingresos" de un inmueble sí deberemos multiplicar el precio el precio por el número de habitaciones cuando sea de los tipos Private room o Shared room

# %% [markdown]
# Ahora bien, multiplicar el precio por el total de habitaciones puede sesgar artificialmente al alza la capacidad de generar ingresos de un inmueble. Ya que si se alquila por habitaciones no es probable que siempre esté al 100%. Por tanto, deberíamos ponderarlo por el porcentaje medio de habitaciones alquiladas.
#
# No tenemos ese dato, pero podemos extraerlo de los datos de availability_365 y dejarlo dinámico por si queremos rehacer el cálculo en el futuro
#
# Podemos crear la variable precio total aplicando apply sobre una función personalizada.

# %%
1-(df.loc[(df.room_type == 'Shared room')].availability_365.mean()/365)
# Out:
# 0.43519872228023837

# %%
1-(df.loc[(df.room_type == 'Private room')].availability_365.mean()/365)
# Out:
# 0.622023437811408

# %%
def crear_precio_total(registro):
    if (registro.beds > 1) & ((registro.room_type == 'Private room')):
        salida = registro.price * registro.beds * 1-(df.loc[(df.room_type == 'Private room')].availability_365.mean()/365)
    elif (registro.beds > 1) & ((registro.room_type == 'Shared room')):
        salida = registro.price * registro.beds * 1-(df.loc[(df.room_type == 'Shared room')].availability_365.mean()/365)
    else:
        salida = registro.price
    return(salida)

df['precio_total'] = round(df.apply(crear_precio_total, axis = 1).astype('float'),2)

# %% [markdown]
# Comprobamos

# %%
df[['room_type','price','beds','precio_total']].head(30)
# Out:
#           room_type  price  beds  precio_total
# 0      Private room     31   1.0         31.00
# 1   Entire home/apt    149   1.0        149.00
# 2   Entire home/apt     92   1.0         92.00
# 3   Entire home/apt    124   2.0        124.00
# 4      Private room     69   2.0        137.62
# 5   Entire home/apt     98   1.0         98.00
# 6   Entire home/apt     80   1.0         80.00
# 7   Entire home/apt     64   2.0         64.00
# 8   Entire home/apt    159   5.0        159.00
# 9   Entire home/apt    132   1.0        132.00
# 10  Entire home/apt     80   1.0         80.00
# 11  Entire home/apt    135   3.0        135.00
# 12     Private room     40   2.0         79.62
# 13  Entire home/apt     81   1.0         81.00
# 14     Private room     21   1.0         21.00
# 15  Entire home/apt    235   2.0        235.00
# 16  Entire home/apt     87   2.0         87.00
# 17     Private room     36   2.0         71.62
# 18     Private room     24   1.0         24.00
# 19  Entire home/apt    161   2.0        161.00
# 20  Entire home/apt    511   2.0        511.00
# 21     Private room     53   1.0         53.00
# 22  Entire home/apt    155   1.0        155.00
# 23  Entire home/apt     65   2.0         65.00
# 24     Private room     20   1.0         20.00
# 25     Private room    103   1.0        103.00
# 26     Private room     80   1.0         80.00
# 27  Entire home/apt     92   1.0         92.00
# 28  Entire home/apt     73   1.0         73.00
# 29  Entire home/apt    193   3.0        193.00

# %% [markdown]
# **Ahora vamos con la ocupación**
#
# La variable que tenemos que nos permite medir esto es availability_365.
#
# Esta variable nos dice el número de días a un año vista que el inmueble NO está ocupado.
#
# Por tanto nos interesaría transformarla a una medida más directa de ocupación, por ejemplo el % del año que SI está ocupada.

# %%
df['ocupacion'] = ((365 - df.availability_365) / 365 * 100).astype('int')
df.head()
# Out:
#       id                                          name host_response_time  \
# 0  21853                          Bright and airy room        no response
# 1  30320                   Great Vacational Apartments        no response
# 2  30959               Beautiful loft in Madrid Center        no response
# 3  40916               Holiday Apartment Madrid Center        no response
# 4  62423  MAGIC ARTISTIC HOUSE IN THE CENTER OF MADRID     within an hour
#
#   host_is_superhost  host_verifications host_has_profile_pic  \
# 0                 f  ['email', 'phone']                    t
# 1                 f  ['email', 'phone']                    t
# 2                 f  ['email', 'phone']                    t
# 3                 f  ['email', 'phone']                    t
# 4                 f  ['email', 'phone']                    t
#
#   host_identity_verified neighbourhood_cleansed                property_type  \
# 0                      t               Cármenes  Private room in rental unit
# 1                      f                    Sol           Entire rental unit
# 2                      f            Embajadores                  Entire loft
# 3                      f            Universidad           Entire rental unit
# 4                      t               Justicia  Private room in rental unit
#
#          room_type                                          amenities  \
# 0     Private room  ["First aid kit", "Wifi", "Kitchen", "Essentia...
# 1  Entire home/apt  ["Heating", "Wifi", "TV with standard cable", ...
# 2  Entire home/apt  ["Breakfast", "Heating", "Wifi", "Smoking allo...
# 3  Entire home/apt  ["Heating", "Wifi", "Pets allowed", "Kitchen",...
# 4     Private room  ["Books and reading material", "First aid kit"...
#
#   has_availability license instant_bookable neighbourhood_group  host_id  \
# 0              yes      no                f              Latina    83531
# 1               no      no                f              Centro   130907
# 2               no      no                f              Centro   132883
# 3               no      no                f              Centro   130907
# 4              yes      no                f              Centro   303845
#
#                    host_since  host_response_rate  host_acceptance_rate  \
# 0  2010-02-21 00:00:00.000000                 0.0                   0.0
# 1  2010-05-24 00:00:00.000000                 0.0                  93.0
# 2  2010-05-26 00:00:00.000000                 0.0                  88.0
# 3  2010-05-24 00:00:00.000000                 0.0                  89.0
# 4  2010-11-29 00:00:00.000000               100.0                 100.0
#
#    host_listings_count  host_total_listings_count  latitude  longitude  \
# 0                  2.0                        2.0  40.40381   -3.74130
# 1                  3.0                        6.0  40.41476   -3.70418
# 2                  1.0                        4.0  40.41259   -3.70105
# 3                  3.0                        6.0  40.42247   -3.70577
# 4                  3.0                        3.0  40.41884   -3.69655
#
#    accommodates  bathrooms  bedrooms  beds  price  minimum_nights  \
# 0             1        1.0       1.0   1.0     31               4
# 1             2        1.0       1.0   1.0    149               5
# 2             2        1.0       1.0   1.0     92               3
# 3             3        1.0       1.0   2.0    124               5
# 4             4        1.5       1.0   2.0     69               1
#
#    maximum_nights  availability_30  availability_60  availability_90  \
# 0              40                0                0                0
# 1             180                0                0                0
# 2             730                0                0                0
# 3             180                0                0                0
# 4              30               13               37               59
#
#    availability_365  number_of_reviews  number_of_reviews_ltm  \
# 0               144                 33                      0
# 1                 0                172                      0
# 2                 0                  8                      0
# 3                 0                 49                      0
# 4               332                219                     44
#
#    number_of_reviews_l30d                first_review  \
# 0                       0  2014-10-10 00:00:00.000000
# 1                       0  2010-07-06 00:00:00.000000
# 2                       0  2015-05-12 00:00:00.000000
# 3                       0  2010-11-01 00:00:00.000000
# 4                       3  2018-05-10 00:00:00.000000
#
#                   last_review  review_scores_rating  review_scores_accuracy  \
# 0  2018-07-15 00:00:00.000000                  4.58                    4.72
# 1  2022-09-26 00:00:00.000000                  4.63                    4.71
# 2  2017-05-30 00:00:00.000000                  4.38                    4.14
# 3  2021-12-11 00:00:00.000000                  4.65                    4.69
# 4  2024-11-24 00:00:00.000000                  4.64                    4.78
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                       4.56                   4.75
# 1                       4.88                   4.82
# 2                       4.38                   4.63
# 3                       4.90                   4.85
# 4                       4.42                   4.79
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         4.82                    4.21                 4.67
# 1                         4.78                    4.90                 4.69
# 2                         4.63                    4.88                 4.25
# 3                         4.79                    4.88                 4.55
# 4                         4.85                    4.97                 4.58
#
#    calculated_host_listings_count  \
# 0                               2
# 1                               3
# 2                               1
# 3                               3
# 4                               3
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            0
# 1                                            3
# 2                                            1
# 3                                            3
# 4                                            1
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             2
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             2
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month  precio_m2  \
# 0                                            0               0.27       2772
# 1                                            0               0.98       6170
# 2                                            0               0.07       6170
# 3                                            0               0.29       6170
# 4                                            0               2.73       6170
#
#    precio_total  ocupacion
# 0         31.00         60
# 1        149.00        100
# 2         92.00        100
# 3        124.00        100
# 4        137.62          9

# %% [markdown]
# ### Transformación de varaibles de análisis

# %% [markdown]
# Algunas de las preguntas semilla están dirigidas a comprobar cómo se comporta el precio o la ocupación según otras variables como el número de habitaciones, la media de valoraciones, etc.
#
# Normalmente podremos hacer mejor estos análisis si discretizamos la variable de análisis. Aplicaremos en:
#
# * Discretización automática:
#     * accommodates
#     * beds
#     * number_of_reviews
#
# * Discretización personalizada:
#     * bedrooms

# %% [markdown]
# **Discretizar bedrooms**
#
# Comenzamos por evaluar la distribución de los datos.

# %%
df.bedrooms.value_counts().sort_index().plot.bar();

# %% [markdown]
# Vamos a discretizar para 1,2,3 y más de 3.
#
# Podemos usar np.select

# %%
condiciones = [df.bedrooms == 0,
               df.bedrooms == 1,
               df.bedrooms == 2,
               df.bedrooms == 3,
               df.bedrooms > 3]

resultados = ['00_Estudio','01_Una','02_Dos','03_Tres','04_Cuatro o mas']

df['bedrooms_disc'] = np.select(condiciones, resultados, default = -999)

# %% [markdown]
# Comprobamos

# %%
df.bedrooms_disc.sort_index().value_counts()
# Out:
# 01_Una             14039
# 02_Dos              5328
# 00_Estudio          3931
# 03_Tres             1872
# 04_Cuatro o mas      703
# Name: bedrooms_disc, dtype: int64

# %%
df.bedrooms_disc.sort_index().value_counts().plot.bar();

# %% [markdown]
# **Discretizar accommodates, beds y number_of_reviews**
#
# Vamos a usar qcut para discritizar con percentiles 0.5, 0.8, 1

# %%
#Generamos la variable discretizada sin labels para saber cuantos accomodates son los que se incluirán en cada grupo
df['accommodates_disc'] = pd.qcut(df.accommodates,[0, 0.5, 0.8, 1])

df['accommodates_disc'].value_counts().sort_index(ascending = False).plot.barh();

# %%
#olvemos a generar la variable con los labels que hemos visto anteriormente
df['accommodates_disc'] = pd.qcut(df.accommodates,[0, 0.5, 0.8, 1],
                                 labels = ['0-3','4','4-16'])

df['accommodates_disc'].value_counts().sort_index(ascending = False).plot.barh();

# %%
df['beds_disc'] = pd.qcut(df.beds,[0, 0.5, 0.8, 1])

df['beds_disc'].value_counts().sort_index(ascending = False).plot.barh();

# %%
df['beds_disc'] = pd.qcut(df.beds,[0, 0.5, 0.8, 1],
                         labels = ['1','3','3-19'])

df['beds_disc'].value_counts().sort_index(ascending = False).plot.barh();

# %%
df['number_of_reviews_disc'] = pd.qcut(df.number_of_reviews,[0, 0.5, 0.8, 1])

df['number_of_reviews_disc'].value_counts().sort_index(ascending = False).plot.barh();

# %%
df['number_of_reviews_disc'] = pd.qcut(df.number_of_reviews,[0, 0.5, 0.8, 1],
                                      labels = ['1-4','5-71','71-1136'])

df['number_of_reviews_disc'].value_counts().sort_index(ascending = False).plot.barh();

# %% [markdown]
# ### Creación de variables con datos externos

# %% [markdown]
# Podríamos hacer varias posibilidades con datos externos pero nos centraremos en buscar un precio aproximado del inmueble según la zona y m2
#
# El precio_m2 nos da el precio según el barrio donde este el inmueble y los metros cuadrados los vamos a estimar según el número de habitaciones que tenga, obteniendo el precio total del inmueble de multiplicar ambas variables
#
# No es perfecto, pero nos servirá de aproximación.

# %% [markdown]
# **Estimación de los metros cuadrados del inmueble**
#
# Vamos usar el siguiente algoritmo:
#
# * cero habitaciones: m2 = 40
# * una habitación: m2 = 50
# * dos habitaciones: m2 = 70
# * tres habitaciones: m2 = 90
# * cuatro habitaciones: m2 = 120
# * cinco o más habitaciones: m2 = 150

# %%
condiciones = [df.bedrooms == 0,
               df.bedrooms == 1,
               df.bedrooms == 2,
               df.bedrooms == 3,
               df.bedrooms == 4,
               df.bedrooms > 4]

resultados = [40,50,70,90,120,150]

df['m2'] = np.select(condiciones, resultados, default = -999)

# %% [markdown]
# Comprobamos

# %%
df['m2'].value_counts()
# Out:
# 50     14039
# 70      5328
# 40      3931
# 90      1872
# 120      427
# 150      276
# Name: m2, dtype: int64

# %% [markdown]
# Ahora ya podemos estimar el precio de compra del inmueble.
#
# Recordamos que al precio que nos sale le quitábamos un 20% por capacidad de negociación.

# %%
df['precio_compra'] = df.m2 * df.precio_m2 * 0.8

# %% [markdown]
# Comprobamos

# %%
df
# Out:
#                         id                                            name  \
# 0                    21853                            Bright and airy room
# 1                    30320                     Great Vacational Apartments
# 2                    30959                 Beautiful loft in Madrid Center
# 3                    40916                 Holiday Apartment Madrid Center
# 4                    62423    MAGIC ARTISTIC HOUSE IN THE CENTER OF MADRID
# ...                    ...                                             ...
# 25868  1308811268356474614                            Habitación tranquila
# 25869  1308816654087147793            Vive Madrid Río con Confort y Estilo
# 25870  1308818613904246041                 Alquilo habitación por 15 días.
# 25871  1308842708819314249  Estudio luminoso y renovado junto a Madrid Río
# 25872  1308864880309321118                 Precioso y Moderno en el Centro
#
#        host_response_time host_is_superhost                host_verifications  \
# 0             no response                 f                ['email', 'phone']
# 1             no response                 f                ['email', 'phone']
# 2             no response                 f                ['email', 'phone']
# 3             no response                 f                ['email', 'phone']
# 4          within an hour                 f                ['email', 'phone']
# ...                   ...               ...                               ...
# 25868      within an hour                 f                         ['phone']
# 25869  within a few hours                 f                ['email', 'phone']
# 25870         no response                 f                ['email', 'phone']
# 25871  within a few hours                 f                ['email', 'phone']
# 25872      within an hour                 f  ['email', 'phone', 'work_email']
#
#       host_has_profile_pic host_identity_verified neighbourhood_cleansed  \
# 0                        t                      t               Cármenes
# 1                        t                      f                    Sol
# 2                        t                      f            Embajadores
# 3                        t                      f            Universidad
# 4                        t                      t               Justicia
# ...                    ...                    ...                    ...
# 25868                    t                      t                 Ventas
# 25869                    t                      t       Puerta del Angel
# 25870                    t                      t                Palacio
# 25871                    t                      t       Puerta del Angel
# 25872                    t                      t                 Atocha
#
#                      property_type        room_type  \
# 0      Private room in rental unit     Private room
# 1               Entire rental unit  Entire home/apt
# 2                      Entire loft  Entire home/apt
# 3               Entire rental unit  Entire home/apt
# 4      Private room in rental unit     Private room
# ...                            ...              ...
# 25868  Private room in rental unit     Private room
# 25869           Entire rental unit  Entire home/apt
# 25870  Private room in rental unit     Private room
# 25871           Entire rental unit  Entire home/apt
# 25872           Entire rental unit  Entire home/apt
#
#                                                amenities has_availability  \
# 0      ["First aid kit", "Wifi", "Kitchen", "Essentia...              yes
# 1      ["Heating", "Wifi", "TV with standard cable", ...               no
# 2      ["Breakfast", "Heating", "Wifi", "Smoking allo...               no
# 3      ["Heating", "Wifi", "Pets allowed", "Kitchen",...               no
# 4      ["Books and reading material", "First aid kit"...              yes
# ...                                                  ...              ...
# 25868                                     ["Wifi", "TV"]              yes
# 25869  ["Wifi", "Kitchen", "Hot water", "Microwave", ...              yes
# 25870                          ["Wifi", "Kitchen", "TV"]              yes
# 25871  ["Wifi", "Kitchen", "Hot water", "Microwave", ...              yes
# 25872  ["Paid parking on premises", "Exercise equipme...              yes
#
#       license instant_bookable neighbourhood_group    host_id  \
# 0          no                f              Latina      83531
# 1          no                f              Centro     130907
# 2          no                f              Centro     132883
# 3          no                f              Centro     130907
# 4          no                f              Centro     303845
# ...       ...              ...                 ...        ...
# 25868      no                f       Ciudad Lineal  548687839
# 25869      no                t              Latina  251333188
# 25870      no                f              Centro  118339834
# 25871      no                t              Latina  251333188
# 25872      no                f          Arganzuela   91095901
#
#                        host_since  host_response_rate  host_acceptance_rate  \
# 0      2010-02-21 00:00:00.000000                 0.0                   0.0
# 1      2010-05-24 00:00:00.000000                 0.0                  93.0
# 2      2010-05-26 00:00:00.000000                 0.0                  88.0
# 3      2010-05-24 00:00:00.000000                 0.0                  89.0
# 4      2010-11-29 00:00:00.000000               100.0                 100.0
# ...                           ...                 ...                   ...
# 25868  2023-11-29 00:00:00.000000               100.0                  69.0
# 25869  2019-03-26 00:00:00.000000               100.0                  67.0
# 25870  2017-02-27 00:00:00.000000                 0.0                  90.0
# 25871  2019-03-26 00:00:00.000000               100.0                  67.0
# 25872  2016-08-21 00:00:00.000000               100.0                 100.0
#
#        host_listings_count  host_total_listings_count   latitude  longitude  \
# 0                      2.0                        2.0  40.403810  -3.741300
# 1                      3.0                        6.0  40.414760  -3.704180
# 2                      1.0                        4.0  40.412590  -3.701050
# 3                      3.0                        6.0  40.422470  -3.705770
# 4                      3.0                        3.0  40.418840  -3.696550
# ...                    ...                        ...        ...        ...
# 25868                  1.0                        2.0  40.429945  -3.653817
# 25869                163.0                      234.0  40.413716  -3.724050
# 25870                  1.0                        1.0  40.413342  -3.709019
# 25871                163.0                      234.0  40.412371  -3.724235
# 25872                  9.0                       12.0  40.397124  -3.679787
#
#        accommodates  bathrooms  bedrooms  beds  price  minimum_nights  \
# 0                 1        1.0       1.0   1.0     31               4
# 1                 2        1.0       1.0   1.0    149               5
# 2                 2        1.0       1.0   1.0     92               3
# 3                 3        1.0       1.0   2.0    124               5
# 4                 4        1.5       1.0   2.0     69               1
# ...             ...        ...       ...   ...    ...             ...
# 25868             2        1.0       1.0   1.0     85               5
# 25869             4        1.0       1.0   2.0    258               1
# 25870             1        1.0       1.0   1.0     20              15
# 25871             2        1.0       1.0   2.0    258               1
# 25872             2        1.0       1.0   1.0    161               7
#
#        maximum_nights  availability_30  availability_60  availability_90  \
# 0                  40                0                0                0
# 1                 180                0                0                0
# 2                 730                0                0                0
# 3                 180                0                0                0
# 4                  30               13               37               59
# ...               ...              ...              ...              ...
# 25868              15               30               60               90
# 25869             365               15               45               75
# 25870              16               29               59               89
# 25871             365               13               43               73
# 25872             300               30               60               90
#
#        availability_365  number_of_reviews  number_of_reviews_ltm  \
# 0                   144                 33                      0
# 1                     0                172                      0
# 2                     0                  8                      0
# 3                     0                 49                      0
# 4                   332                219                     44
# ...                 ...                ...                    ...
# 25868               365                  0                      0
# 25869               350                  0                      0
# 25870               364                  0                      0
# 25871               348                  0                      0
# 25872                90                  0                      0
#
#        number_of_reviews_l30d                first_review  \
# 0                           0  2014-10-10 00:00:00.000000
# 1                           0  2010-07-06 00:00:00.000000
# 2                           0  2015-05-12 00:00:00.000000
# 3                           0  2010-11-01 00:00:00.000000
# 4                           3  2018-05-10 00:00:00.000000
# ...                       ...                         ...
# 25868                       0  2023-11-29 00:00:00.000000
# 25869                       0  2019-03-26 00:00:00.000000
# 25870                       0  2017-02-27 00:00:00.000000
# 25871                       0  2019-03-26 00:00:00.000000
# 25872                       0  2016-08-21 00:00:00.000000
#
#                       last_review  review_scores_rating  \
# 0      2018-07-15 00:00:00.000000                  4.58
# 1      2022-09-26 00:00:00.000000                  4.63
# 2      2017-05-30 00:00:00.000000                  4.38
# 3      2021-12-11 00:00:00.000000                  4.65
# 4      2024-11-24 00:00:00.000000                  4.64
# ...                           ...                   ...
# 25868  2023-11-29 00:00:00.000000                  0.00
# 25869  2019-03-26 00:00:00.000000                  0.00
# 25870  2017-02-27 00:00:00.000000                  0.00
# 25871  2019-03-26 00:00:00.000000                  0.00
# 25872  2016-08-21 00:00:00.000000                  0.00
#
#        review_scores_accuracy  review_scores_cleanliness  \
# 0                        4.72                       4.56
# 1                        4.71                       4.88
# 2                        4.14                       4.38
# 3                        4.69                       4.90
# 4                        4.78                       4.42
# ...                       ...                        ...
# 25868                    0.00                       0.00
# 25869                    0.00                       0.00
# 25870                    0.00                       0.00
# 25871                    0.00                       0.00
# 25872                    0.00                       0.00
#
#        review_scores_checkin  review_scores_communication  \
# 0                       4.75                         4.82
# 1                       4.82                         4.78
# 2                       4.63                         4.63
# 3                       4.85                         4.79
# 4                       4.79                         4.85
# ...                      ...                          ...
# 25868                   0.00                         0.00
# 25869                   0.00                         0.00
# 25870                   0.00                         0.00
# 25871                   0.00                         0.00
# 25872                   0.00                         0.00
#
#        review_scores_location  review_scores_value  \
# 0                        4.21                 4.67
# 1                        4.90                 4.69
# 2                        4.88                 4.25
# 3                        4.88                 4.55
# 4                        4.97                 4.58
# ...                       ...                  ...
# 25868                    0.00                 0.00
# 25869                    0.00                 0.00
# 25870                    0.00                 0.00
# 25871                    0.00                 0.00
# 25872                    0.00                 0.00
#
#        calculated_host_listings_count  \
# 0                                   2
# 1                                   3
# 2                                   1
# 3                                   3
# 4                                   3
# ...                               ...
# 25868                               1
# 25869                              19
# 25870                               1
# 25871                              19
# 25872                               6
#
#        calculated_host_listings_count_entire_homes  \
# 0                                                0
# 1                                                3
# 2                                                1
# 3                                                3
# 4                                                1
# ...                                            ...
# 25868                                            0
# 25869                                           19
# 25870                                            0
# 25871                                           19
# 25872                                            6
#
#        calculated_host_listings_count_private_rooms  \
# 0                                                 2
# 1                                                 0
# 2                                                 0
# 3                                                 0
# 4                                                 2
# ...                                             ...
# 25868                                             1
# 25869                                             0
# 25870                                             1
# 25871                                             0
# 25872                                             0
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month  \
# 0                                                0               0.27
# 1                                                0               0.98
# 2                                                0               0.07
# 3                                                0               0.29
# 4                                                0               2.73
# ...                                            ...                ...
# 25868                                            0               0.00
# 25869                                            0               0.00
# 25870                                            0               0.00
# 25871                                            0               0.00
# 25872                                            0               0.00
#
#        precio_m2  precio_total  ocupacion bedrooms_disc accommodates_disc  \
# 0           2772         31.00         60        01_Una               0-3
# 1           6170        149.00        100        01_Una               0-3
# 2           6170         92.00        100        01_Una               0-3
# 3           6170        124.00        100        01_Una               0-3
# 4           6170        137.62          9        01_Una                 4
# ...          ...           ...        ...           ...               ...
# 25868       3676         85.00          0        01_Una               0-3
# 25869       2772        258.00          4        01_Una                 4
# 25870       6170         20.00          0        01_Una               0-3
# 25871       2772        258.00          4        01_Una               0-3
# 25872       4850        161.00         75        01_Una               0-3
#
#       beds_disc number_of_reviews_disc  m2  precio_compra
# 0             1                   5-71  50       110880.0
# 1             1                71-1136  50       246800.0
# 2             1                    1-4  50       246800.0
# 3             3                   5-71  50       246800.0
# 4             3                71-1136  50       246800.0
# ...         ...                    ...  ..            ...
# 25868         1                    1-4  50       147040.0
# 25869         3                    1-4  50       110880.0
# 25870         1                    1-4  50       246800.0
# 25871         3                    1-4  50       110880.0
# 25872         1                    1-4  50       194000.0
#
# [25873 rows x 60 columns]

# %%
df[['bedrooms','m2','neighbourhood_cleansed','precio_m2','precio_compra']].head(20)
# Out:
#     bedrooms  m2 neighbourhood_cleansed  precio_m2  precio_compra
# 0        1.0  50               Cármenes       2772       110880.0
# 1        1.0  50                    Sol       6170       246800.0
# 2        1.0  50            Embajadores       6170       246800.0
# 3        1.0  50            Universidad       6170       246800.0
# 4        1.0  50               Justicia       6170       246800.0
# 5        1.0  50            Universidad       6170       246800.0
# 6        1.0  50            Universidad       6170       246800.0
# 7        1.0  50            Universidad       6170       246800.0
# 8        3.0  90            Embajadores       6170       444240.0
# 9        1.0  50              Recoletos       7846       313840.0
# 10       1.0  50            Embajadores       6170       246800.0
# 11       3.0  90            Embajadores       6170       444240.0
# 12       3.0  90            Universidad       6170       444240.0
# 13       1.0  50               Valverde       4038       161520.0
# 14       1.0  50           Pueblo Nuevo       3676       147040.0
# 15       2.0  70               Justicia       6170       345520.0
# 16       1.0  50             Rios Rosas       6665       266600.0
# 17       1.0  50                Palacio       6170       246800.0
# 18       1.0  50            Los Angeles       2070        82800.0
# 19       1.0  50              Trafalgar       6665       266600.0

# %% [markdown]
# Ahora vamos a poner un ejemplo de qué otro tipo de variables podemos construir.
#
# En este caso podríamos hacer mucho con las coordenadas x,y.
#
# Ya que en turismo la localización es muy importante, vamos a calcular las distancias a la Puerta del Sol como referencia de turismo en Madrid, pero podríamos calcularla a cualquier punto de interés teniendo las coordenadas
#
# Para ello buscamos en Google su longitud y latitud: https://www.123coordenadas.com/coordinates/81497-puerta-del-sol-madrid
#
# * Latitud: 40.4167278
# * Longitud: -3.7033387

# %% [markdown]
# **Cálculo de la distancia de cada inmueble a la Puerta del Sol**
#
# Dada la curvatura de la tierra la distancia entre dos puntos a partir de su latitud y longitud se calcula con una fórmula que se llama distancia de Haversine.
#
# Una búsqueda en Google nos da una función ya construída para calcularla que podemos adaptar: https://stackoverflow.com/questions/4913349/haversine-formula-in-python-bearing-and-distance-between-two-gps-points

# %%
from math import radians, cos, sin, asin, sqrt

def haversine(lat1, lon1, lat2, lon2):

      R = 6372.8 #En km, si usas millas tienes que cambiarlo por 3959.87433

      dLat = radians(lat2 - lat1)
      dLon = radians(lon2 - lon1)
      lat1 = radians(lat1)
      lat2 = radians(lat2)

      a = sin(dLat/2)**2 + cos(lat1)*cos(lat2)*sin(dLon/2)**2
      c = 2*asin(sqrt(a))

      return R * c

# %% [markdown]
# Creamos la variable

# %%
#Las coordenadas de la Puerta del Sol serán lat1 y lon1
lat1 = 40.4167278
lon1 = -3.7033387

df['pdi_sol'] = df.apply(lambda registro: haversine(lat1,lon1,registro.latitude,registro.longitude),axis = 1)

# %% [markdown]
# Comprobamos revisando la distancia media por distritos.

# %%
df.groupby('neighbourhood_cleansed').pdi_sol.mean().sort_values()
# Out:
# neighbourhood_cleansed
# Sol                              0.270060
# Cortes                           0.550317
# Palacio                          0.801122
# Embajadores                      0.811360
# Justicia                         0.842936
# Universidad                      0.880365
# Imperial                         1.584212
# Argüelles                        1.588717
# Acacias                          1.630370
# Palos de Moguer                  1.644849
# Jerónimos                        1.667782
# Recoletos                        1.756636
# Trafalgar                        1.765892
# Arapiles                         1.941160
# Almagro                          2.005605
# Casa de Campo                    2.143793
# Gaztambide                       2.181128
# Delicias                         2.344474
# Ibiza                            2.354268
# Chopera                          2.364714
# Niño Jesús                       2.521784
# Puerta del Angel                 2.526765
# Castellana                       2.526939
# Pacífico                         2.549022
# Goya                             2.595854
# Atocha                           2.627403
# Comillas                         2.672477
# Rios Rosas                       2.878548
# Lista                            2.906080
# Vallehermoso                     2.936803
# Estrella                         3.077296
# San Isidro                       3.178707
# Moscardó                         3.228768
# Cármenes                         3.230308
# Opañel                           3.274085
# Adelfas                          3.295488
# Fuente del Berro                 3.356879
# Legazpi                          3.372181
# El Viso                          3.493621
# Guindalera                       3.575633
# Almendrales                      3.584610
# Prosperidad                      3.855099
# Cuatro Caminos                   3.871609
# Bellas Vistas                    3.901627
# Lucero                           3.967336
# Pradolongo                       3.974317
# Media Legua                      3.990064
# Numancia                         4.015238
# Zofío                            4.035317
# San Diego                        4.078612
# Ciudad Jardín                    4.208915
# Ventas                           4.403059
# Abrantes                         4.569514
# Vista Alegre                     4.643947
# Orcasur                          4.667602
# Ciudad Universitaria             4.672113
# Hispanoamérica                   4.777324
# Berruguete                       4.780010
# Castillejos                      4.837934
# Concepción                       4.875553
# Palomeras Bajas                  4.895311
# Marroquina                       4.933535
# Entrevías                        4.999373
# Puerta Bonita                    5.002241
# San Pascual                      5.058458
# Quintana                         5.154957
# San Fermín                       5.200421
# Fontarrón                        5.202679
# Vinateros                        5.228790
# Aluche                           5.401501
# Nueva España                     5.402144
# Orcasitas                        5.414858
# San Juan Bautista                5.417560
# Valdezarza                       5.474544
# Portazgo                         5.529599
# Valdeacederas                    5.541734
# Pueblo Nuevo                     5.606537
# Colina                           5.801149
# Almenara                         5.979018
# Pavones                          6.191155
# Castilla                         6.293330
# Campamento                       6.296350
# Palomeras Sureste                6.298262
# Horcajo                          6.409466
# Salvador                         6.644185
# Pilar                            6.653946
# Los Angeles                      6.805365
# Costillares                      6.880078
# Simancas                         6.893057
# Buenavista                       7.025040
# La Paz                           7.031196
# Peñagrande                       7.046879
# Amposta                          7.055718
# Los Rosales                      7.176334
# Aguilas                          7.180964
# Piovera                          7.189014
# Canillas                         7.247294
# Arcos                            7.380365
# Fuentelareina                    7.390512
# Apostol Santiago                 7.538356
# Hellín                           7.548340
# Cuatro Vientos                   7.753999
# Aravaca                          7.799027
# Pinar del Rey                    7.916590
# Butarque                         7.982009
# Ambroz                           8.147233
# San Cristobal                    8.351542
# Canillejas                       8.354750
# San Andrés                       8.357949
# Rosas                            8.405929
# Mirasierra                       8.552994
# Palomas                          8.556933
# Valdemarín                       8.746737
# Santa Eugenia                    8.767053
# Valverde                         8.882767
# Casco Histórico de Vallecas      9.226570
# Valdefuentes                     9.238484
# Casco Histórico de Vicálvaro     9.317614
# El Goloso                       10.367464
# Alameda de Osuna                10.559552
# Corralejos                      10.580607
# Rejas                           10.795154
# Aeropuerto                      11.462304
# Timón                           11.516857
# El Plantío                      11.742261
# Casco Histórico de Barajas      12.298297
# El Pardo                        13.277209
# Name: pdi_sol, dtype: float64

# %% [markdown]
# ## Creación de la Target
#
# Consideramos rentable un inmueble si lo podemos rentabilizar en máximo 10 años, por lo que calculamos la target = 1 como aquellos inmuebles cuyo precio_compra/10 < precio_total * ocupacion * 10. Es decir, que si los ingresos anuales de una vivienda son superiores al 10% del valor de la vivienda, es rentable

# %%
df['pisos_rentables'] = np.where(df['precio_compra']/10 > df['precio_total'] * df['ocupacion'] * 10, 0, 1)

# %% [markdown]
# La target voy a dejarla en el df pero habrá que separarla en el futuro para hacer las predicciones

# %% [markdown]
# Cuando vayamos a realizar el proyecto de automation, necesitaremos borrar las columnas relacionadas con la target pero ahora mismo esas columnas son necesarias para el proyecto de discovery, por lo que voy a dejar el código comentado para rescatarlo mas adelante

# %%
#df = df.drop(columns=['precio_compra','precio_total','ocupacion'])

# %%
df
# Out:
#                         id                                            name  \
# 0                    21853                            Bright and airy room
# 1                    30320                     Great Vacational Apartments
# 2                    30959                 Beautiful loft in Madrid Center
# 3                    40916                 Holiday Apartment Madrid Center
# 4                    62423    MAGIC ARTISTIC HOUSE IN THE CENTER OF MADRID
# ...                    ...                                             ...
# 25868  1308811268356474614                            Habitación tranquila
# 25869  1308816654087147793            Vive Madrid Río con Confort y Estilo
# 25870  1308818613904246041                 Alquilo habitación por 15 días.
# 25871  1308842708819314249  Estudio luminoso y renovado junto a Madrid Río
# 25872  1308864880309321118                 Precioso y Moderno en el Centro
#
#        host_response_time host_is_superhost                host_verifications  \
# 0             no response                 f                ['email', 'phone']
# 1             no response                 f                ['email', 'phone']
# 2             no response                 f                ['email', 'phone']
# 3             no response                 f                ['email', 'phone']
# 4          within an hour                 f                ['email', 'phone']
# ...                   ...               ...                               ...
# 25868      within an hour                 f                         ['phone']
# 25869  within a few hours                 f                ['email', 'phone']
# 25870         no response                 f                ['email', 'phone']
# 25871  within a few hours                 f                ['email', 'phone']
# 25872      within an hour                 f  ['email', 'phone', 'work_email']
#
#       host_has_profile_pic host_identity_verified neighbourhood_cleansed  \
# 0                        t                      t               Cármenes
# 1                        t                      f                    Sol
# 2                        t                      f            Embajadores
# 3                        t                      f            Universidad
# 4                        t                      t               Justicia
# ...                    ...                    ...                    ...
# 25868                    t                      t                 Ventas
# 25869                    t                      t       Puerta del Angel
# 25870                    t                      t                Palacio
# 25871                    t                      t       Puerta del Angel
# 25872                    t                      t                 Atocha
#
#                      property_type        room_type  \
# 0      Private room in rental unit     Private room
# 1               Entire rental unit  Entire home/apt
# 2                      Entire loft  Entire home/apt
# 3               Entire rental unit  Entire home/apt
# 4      Private room in rental unit     Private room
# ...                            ...              ...
# 25868  Private room in rental unit     Private room
# 25869           Entire rental unit  Entire home/apt
# 25870  Private room in rental unit     Private room
# 25871           Entire rental unit  Entire home/apt
# 25872           Entire rental unit  Entire home/apt
#
#                                                amenities has_availability  \
# 0      ["First aid kit", "Wifi", "Kitchen", "Essentia...              yes
# 1      ["Heating", "Wifi", "TV with standard cable", ...               no
# 2      ["Breakfast", "Heating", "Wifi", "Smoking allo...               no
# 3      ["Heating", "Wifi", "Pets allowed", "Kitchen",...               no
# 4      ["Books and reading material", "First aid kit"...              yes
# ...                                                  ...              ...
# 25868                                     ["Wifi", "TV"]              yes
# 25869  ["Wifi", "Kitchen", "Hot water", "Microwave", ...              yes
# 25870                          ["Wifi", "Kitchen", "TV"]              yes
# 25871  ["Wifi", "Kitchen", "Hot water", "Microwave", ...              yes
# 25872  ["Paid parking on premises", "Exercise equipme...              yes
#
#       license instant_bookable neighbourhood_group    host_id  \
# 0          no                f              Latina      83531
# 1          no                f              Centro     130907
# 2          no                f              Centro     132883
# 3          no                f              Centro     130907
# 4          no                f              Centro     303845
# ...       ...              ...                 ...        ...
# 25868      no                f       Ciudad Lineal  548687839
# 25869      no                t              Latina  251333188
# 25870      no                f              Centro  118339834
# 25871      no                t              Latina  251333188
# 25872      no                f          Arganzuela   91095901
#
#                        host_since  host_response_rate  host_acceptance_rate  \
# 0      2010-02-21 00:00:00.000000                 0.0                   0.0
# 1      2010-05-24 00:00:00.000000                 0.0                  93.0
# 2      2010-05-26 00:00:00.000000                 0.0                  88.0
# 3      2010-05-24 00:00:00.000000                 0.0                  89.0
# 4      2010-11-29 00:00:00.000000               100.0                 100.0
# ...                           ...                 ...                   ...
# 25868  2023-11-29 00:00:00.000000               100.0                  69.0
# 25869  2019-03-26 00:00:00.000000               100.0                  67.0
# 25870  2017-02-27 00:00:00.000000                 0.0                  90.0
# 25871  2019-03-26 00:00:00.000000               100.0                  67.0
# 25872  2016-08-21 00:00:00.000000               100.0                 100.0
#
#        host_listings_count  host_total_listings_count   latitude  longitude  \
# 0                      2.0                        2.0  40.403810  -3.741300
# 1                      3.0                        6.0  40.414760  -3.704180
# 2                      1.0                        4.0  40.412590  -3.701050
# 3                      3.0                        6.0  40.422470  -3.705770
# 4                      3.0                        3.0  40.418840  -3.696550
# ...                    ...                        ...        ...        ...
# 25868                  1.0                        2.0  40.429945  -3.653817
# 25869                163.0                      234.0  40.413716  -3.724050
# 25870                  1.0                        1.0  40.413342  -3.709019
# 25871                163.0                      234.0  40.412371  -3.724235
# 25872                  9.0                       12.0  40.397124  -3.679787
#
#        accommodates  bathrooms  bedrooms  beds  price  minimum_nights  \
# 0                 1        1.0       1.0   1.0     31               4
# 1                 2        1.0       1.0   1.0    149               5
# 2                 2        1.0       1.0   1.0     92               3
# 3                 3        1.0       1.0   2.0    124               5
# 4                 4        1.5       1.0   2.0     69               1
# ...             ...        ...       ...   ...    ...             ...
# 25868             2        1.0       1.0   1.0     85               5
# 25869             4        1.0       1.0   2.0    258               1
# 25870             1        1.0       1.0   1.0     20              15
# 25871             2        1.0       1.0   2.0    258               1
# 25872             2        1.0       1.0   1.0    161               7
#
#        maximum_nights  availability_30  availability_60  availability_90  \
# 0                  40                0                0                0
# 1                 180                0                0                0
# 2                 730                0                0                0
# 3                 180                0                0                0
# 4                  30               13               37               59
# ...               ...              ...              ...              ...
# 25868              15               30               60               90
# 25869             365               15               45               75
# 25870              16               29               59               89
# 25871             365               13               43               73
# 25872             300               30               60               90
#
#        availability_365  number_of_reviews  number_of_reviews_ltm  \
# 0                   144                 33                      0
# 1                     0                172                      0
# 2                     0                  8                      0
# 3                     0                 49                      0
# 4                   332                219                     44
# ...                 ...                ...                    ...
# 25868               365                  0                      0
# 25869               350                  0                      0
# 25870               364                  0                      0
# 25871               348                  0                      0
# 25872                90                  0                      0
#
#        number_of_reviews_l30d                first_review  \
# 0                           0  2014-10-10 00:00:00.000000
# 1                           0  2010-07-06 00:00:00.000000
# 2                           0  2015-05-12 00:00:00.000000
# 3                           0  2010-11-01 00:00:00.000000
# 4                           3  2018-05-10 00:00:00.000000
# ...                       ...                         ...
# 25868                       0  2023-11-29 00:00:00.000000
# 25869                       0  2019-03-26 00:00:00.000000
# 25870                       0  2017-02-27 00:00:00.000000
# 25871                       0  2019-03-26 00:00:00.000000
# 25872                       0  2016-08-21 00:00:00.000000
#
#                       last_review  review_scores_rating  \
# 0      2018-07-15 00:00:00.000000                  4.58
# 1      2022-09-26 00:00:00.000000                  4.63
# 2      2017-05-30 00:00:00.000000                  4.38
# 3      2021-12-11 00:00:00.000000                  4.65
# 4      2024-11-24 00:00:00.000000                  4.64
# ...                           ...                   ...
# 25868  2023-11-29 00:00:00.000000                  0.00
# 25869  2019-03-26 00:00:00.000000                  0.00
# 25870  2017-02-27 00:00:00.000000                  0.00
# 25871  2019-03-26 00:00:00.000000                  0.00
# 25872  2016-08-21 00:00:00.000000                  0.00
#
#        review_scores_accuracy  review_scores_cleanliness  \
# 0                        4.72                       4.56
# 1                        4.71                       4.88
# 2                        4.14                       4.38
# 3                        4.69                       4.90
# 4                        4.78                       4.42
# ...                       ...                        ...
# 25868                    0.00                       0.00
# 25869                    0.00                       0.00
# 25870                    0.00                       0.00
# 25871                    0.00                       0.00
# 25872                    0.00                       0.00
#
#        review_scores_checkin  review_scores_communication  \
# 0                       4.75                         4.82
# 1                       4.82                         4.78
# 2                       4.63                         4.63
# 3                       4.85                         4.79
# 4                       4.79                         4.85
# ...                      ...                          ...
# 25868                   0.00                         0.00
# 25869                   0.00                         0.00
# 25870                   0.00                         0.00
# 25871                   0.00                         0.00
# 25872                   0.00                         0.00
#
#        review_scores_location  review_scores_value  \
# 0                        4.21                 4.67
# 1                        4.90                 4.69
# 2                        4.88                 4.25
# 3                        4.88                 4.55
# 4                        4.97                 4.58
# ...                       ...                  ...
# 25868                    0.00                 0.00
# 25869                    0.00                 0.00
# 25870                    0.00                 0.00
# 25871                    0.00                 0.00
# 25872                    0.00                 0.00
#
#        calculated_host_listings_count  \
# 0                                   2
# 1                                   3
# 2                                   1
# 3                                   3
# 4                                   3
# ...                               ...
# 25868                               1
# 25869                              19
# 25870                               1
# 25871                              19
# 25872                               6
#
#        calculated_host_listings_count_entire_homes  \
# 0                                                0
# 1                                                3
# 2                                                1
# 3                                                3
# 4                                                1
# ...                                            ...
# 25868                                            0
# 25869                                           19
# 25870                                            0
# 25871                                           19
# 25872                                            6
#
#        calculated_host_listings_count_private_rooms  \
# 0                                                 2
# 1                                                 0
# 2                                                 0
# 3                                                 0
# 4                                                 2
# ...                                             ...
# 25868                                             1
# 25869                                             0
# 25870                                             1
# 25871                                             0
# 25872                                             0
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month  \
# 0                                                0               0.27
# 1                                                0               0.98
# 2                                                0               0.07
# 3                                                0               0.29
# 4                                                0               2.73
# ...                                            ...                ...
# 25868                                            0               0.00
# 25869                                            0               0.00
# 25870                                            0               0.00
# 25871                                            0               0.00
# 25872                                            0               0.00
#
#        precio_m2  precio_total  ocupacion bedrooms_disc accommodates_disc  \
# 0           2772         31.00         60        01_Una               0-3
# 1           6170        149.00        100        01_Una               0-3
# 2           6170         92.00        100        01_Una               0-3
# 3           6170        124.00        100        01_Una               0-3
# 4           6170        137.62          9        01_Una                 4
# ...          ...           ...        ...           ...               ...
# 25868       3676         85.00          0        01_Una               0-3
# 25869       2772        258.00          4        01_Una                 4
# 25870       6170         20.00          0        01_Una               0-3
# 25871       2772        258.00          4        01_Una               0-3
# 25872       4850        161.00         75        01_Una               0-3
#
#       beds_disc number_of_reviews_disc  m2  precio_compra   pdi_sol  \
# 0             1                   5-71  50       110880.0  3.521406
# 1             1                71-1136  50       246800.0  0.230175
# 2             1                    1-4  50       246800.0  0.499379
# 3             3                   5-71  50       246800.0  0.671046
# 4             3                71-1136  50       246800.0  0.621024
# ...         ...                    ...  ..            ...       ...
# 25868         1                    1-4  50       147040.0  4.443394
# 25869         3                    1-4  50       110880.0  1.785622
# 25870         1                    1-4  50       246800.0  0.610945
# 25871         3                    1-4  50       110880.0  1.834746
# 25872         1                    1-4  50       194000.0  2.955180
#
#        pisos_rentables
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    0
# ...                ...
# 25868                0
# 25869                0
# 25870                0
# 25871                0
# 25872                1
#
# [25873 rows x 62 columns]

# %% [markdown]
# ## GUARDAMOS EN EL DATAMART

# %% [markdown]
# Vamos a guardar esta version como df_preparado

# %%
df.to_sql('df_preparado', con = conn_lite, if_exists = 'replace')
# Out:
# 25873

# %%
cursor = conn_lite.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table'")
tablas = cursor.fetchall()
tablas
# Out:
# [('listings',),
#  ('listings_det',),
#  ('calendar',),
#  ('neigh',),
#  ('target',),
#  ('id_df',),
#  ('precio_total_df',),
#  ('extras_df',),
#  ('cat',),
#  ('num',),
#  ('precio_m2',),
#  ('df_preparado',)]

# %%
# Cerrar conexión con base de datos
conn_lite.close()
