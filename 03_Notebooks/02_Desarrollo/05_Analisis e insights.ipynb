# %% [markdown]
# # ANALISIS E INSIGHTS

# %% [markdown]
# ## SET UP

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import sqlalchemy as sa
import sqlite3

#Automcompletar rápido
# %config IPCompleter.greedy=True

pd.options.display.max_columns = None

# %% [markdown]
# ## CARGA DE DATOS

# %%
# Ruta del proyecto
ruta_proyecto = 'C:/Users/Oscar/OneDrive - FM4/Escritorio/EVOLVE/Data Science/Proyecto-Master-DataScience-Evolve-OscarFraile'

# Nombre del fichero de datos
nombre_fichero_datos = 'airbnb2025.db'

# Ruta completa
ruta_completa = ruta_proyecto + '/02_Datos/01_Originales/' + nombre_fichero_datos

# Conexión sqlite3
conn_lite = sqlite3.connect(ruta_completa)

ruta_db = ruta_proyecto + '/02_Datos/01_Originales/airbnb2025.db' 

df = pd.read_sql('SELECT * FROM df_preparado', conn_lite)

df.head()
# Out:
#    index     id                                          name  \
# 0      0  21853                          Bright and airy room
# 1      1  30320                   Great Vacational Apartments
# 2      2  30959               Beautiful loft in Madrid Center
# 3      3  40916               Holiday Apartment Madrid Center
# 4      4  62423  MAGIC ARTISTIC HOUSE IN THE CENTER OF MADRID
#
#   host_response_time host_is_superhost  host_verifications  \
# 0        no response                 f  ['email', 'phone']
# 1        no response                 f  ['email', 'phone']
# 2        no response                 f  ['email', 'phone']
# 3        no response                 f  ['email', 'phone']
# 4     within an hour                 f  ['email', 'phone']
#
#   host_has_profile_pic host_identity_verified neighbourhood_cleansed  \
# 0                    t                      t               Cármenes
# 1                    t                      f                    Sol
# 2                    t                      f            Embajadores
# 3                    t                      f            Universidad
# 4                    t                      t               Justicia
#
#                  property_type        room_type  \
# 0  Private room in rental unit     Private room
# 1           Entire rental unit  Entire home/apt
# 2                  Entire loft  Entire home/apt
# 3           Entire rental unit  Entire home/apt
# 4  Private room in rental unit     Private room
#
#                                            amenities has_availability license  \
# 0  ["First aid kit", "Wifi", "Kitchen", "Essentia...              yes      no
# 1  ["Heating", "Wifi", "TV with standard cable", ...               no      no
# 2  ["Breakfast", "Heating", "Wifi", "Smoking allo...               no      no
# 3  ["Heating", "Wifi", "Pets allowed", "Kitchen",...               no      no
# 4  ["Books and reading material", "First aid kit"...              yes      no
#
#   instant_bookable neighbourhood_group  host_id                  host_since  \
# 0                f              Latina    83531  2010-02-21 00:00:00.000000
# 1                f              Centro   130907  2010-05-24 00:00:00.000000
# 2                f              Centro   132883  2010-05-26 00:00:00.000000
# 3                f              Centro   130907  2010-05-24 00:00:00.000000
# 4                f              Centro   303845  2010-11-29 00:00:00.000000
#
#    host_response_rate  host_acceptance_rate  host_listings_count  \
# 0                 0.0                   0.0                  2.0
# 1                 0.0                  93.0                  3.0
# 2                 0.0                  88.0                  1.0
# 3                 0.0                  89.0                  3.0
# 4               100.0                 100.0                  3.0
#
#    host_total_listings_count  latitude  longitude  accommodates  bathrooms  \
# 0                        2.0  40.40381   -3.74130             1        1.0
# 1                        6.0  40.41476   -3.70418             2        1.0
# 2                        4.0  40.41259   -3.70105             2        1.0
# 3                        6.0  40.42247   -3.70577             3        1.0
# 4                        3.0  40.41884   -3.69655             4        1.5
#
#    bedrooms  beds  price  minimum_nights  maximum_nights  availability_30  \
# 0       1.0   1.0     31               4              40                0
# 1       1.0   1.0    149               5             180                0
# 2       1.0   1.0     92               3             730                0
# 3       1.0   2.0    124               5             180                0
# 4       1.0   2.0     69               1              30               13
#
#    availability_60  availability_90  availability_365  number_of_reviews  \
# 0                0                0               144                 33
# 1                0                0                 0                172
# 2                0                0                 0                  8
# 3                0                0                 0                 49
# 4               37               59               332                219
#
#    number_of_reviews_ltm  number_of_reviews_l30d                first_review  \
# 0                      0                       0  2014-10-10 00:00:00.000000
# 1                      0                       0  2010-07-06 00:00:00.000000
# 2                      0                       0  2015-05-12 00:00:00.000000
# 3                      0                       0  2010-11-01 00:00:00.000000
# 4                     44                       3  2018-05-10 00:00:00.000000
#
#                   last_review  review_scores_rating  review_scores_accuracy  \
# 0  2018-07-15 00:00:00.000000                  4.58                    4.72
# 1  2022-09-26 00:00:00.000000                  4.63                    4.71
# 2  2017-05-30 00:00:00.000000                  4.38                    4.14
# 3  2021-12-11 00:00:00.000000                  4.65                    4.69
# 4  2024-11-24 00:00:00.000000                  4.64                    4.78
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                       4.56                   4.75
# 1                       4.88                   4.82
# 2                       4.38                   4.63
# 3                       4.90                   4.85
# 4                       4.42                   4.79
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         4.82                    4.21                 4.67
# 1                         4.78                    4.90                 4.69
# 2                         4.63                    4.88                 4.25
# 3                         4.79                    4.88                 4.55
# 4                         4.85                    4.97                 4.58
#
#    calculated_host_listings_count  \
# 0                               2
# 1                               3
# 2                               1
# 3                               3
# 4                               3
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            0
# 1                                            3
# 2                                            1
# 3                                            3
# 4                                            1
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             2
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             2
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month  precio_m2  \
# 0                                            0               0.27       2772
# 1                                            0               0.98       6170
# 2                                            0               0.07       6170
# 3                                            0               0.29       6170
# 4                                            0               2.73       6170
#
#    precio_total  ocupacion bedrooms_disc accommodates_disc beds_disc  \
# 0         31.00         60        01_Una               0-3         1
# 1        149.00        100        01_Una               0-3         1
# 2         92.00        100        01_Una               0-3         1
# 3        124.00        100        01_Una               0-3         3
# 4        137.62          9        01_Una                 4         3
#
#   number_of_reviews_disc  m2  precio_compra   pdi_sol  pisos_rentables
# 0                   5-71  50       110880.0  3.521406                1
# 1                71-1136  50       246800.0  0.230175                1
# 2                    1-4  50       246800.0  0.499379                1
# 3                   5-71  50       246800.0  0.671046                1
# 4                71-1136  50       246800.0  0.621024                0

# %% [markdown]
# ## ANALISIS

# %% [markdown]
# ### Analisis sobre el precio

# %% [markdown]
# **¿Cual es el precio medio? ¿y el rango de precios?¿Y por distritos?¿Y por barrios?**
#
# **¿Cual es el ranking de distritos y barrios por precio medio de alquiler?**

# %%
df.precio_total.describe()
# Out:
# count    25873.000000
# mean       125.546177
# std        134.176521
# min         20.000000
# 25%         67.000000
# 50%        100.000000
# 75%        142.000000
# max       5099.620000
# Name: precio_total, dtype: float64

# %% [markdown]
# Vemos que hay al menos un atípico por la parte de arriba que sesga la media, por tanto vamos a usar la mediana como medida de centralización más fiable.

# %%
df.precio_total.median()
# Out:
# 100.0

# %%
df.groupby('neighbourhood_group').precio_total.median().sort_values(ascending = False)
# Out:
# neighbourhood_group
# Salamanca             120.00
# Centro                111.00
# Chamartín             109.00
# Chamberí              104.00
# Moncloa               101.00
# Retiro                 98.00
# Tetuán                 92.00
# San Blas               89.81
# Hortaleza              86.00
# Arganzuela             85.00
# Fuencarral             82.50
# Barajas                79.00
# Ciudad Lineal          78.00
# Latina                 70.00
# Puente de Vallecas     65.50
# Carabanchel            65.00
# Villa de Vallecas      60.00
# Villaverde             60.00
# Usera                  59.00
# Vicálvaro              51.00
# Moratalaz              47.50
# Name: precio_total, dtype: float64

# %% [markdown]
# Nos llama la atención el dato de San Blas, vamos a verlo con más detalle a ver qué está pasando.

# %%
df.loc[df.neighbourhood_group == 'San Blas'].sort_values('precio_total',ascending = False).head(10)
# Out:
#        index                   id  \
# 3305    3305             20842089
# 6359    6359             35155733
# 12021  12021   700011597005161293
# 5769    5769             34569100
# 6165    6165             34970236
# 6307    6307             35137335
# 6030    6030             34796669
# 5873    5873             34614302
# 17720  17720  1029047360999100969
# 11511  11511   668761907769527441
#
#                                                     name  host_response_time  \
# 3305         Mas cerca del Wanda Metropolitano imposible         no response
# 6359           Cosy apartment near Metropolitano Stadium         no response
# 12021                               Habitación reformada         no response
# 5769    Final Champions close of Wanda Stadium.Two Rooms         no response
# 6165   Habitaciones cerca Wanda Metropolitano (Champi...         no response
# 6307                      Bedrooms Champion League Final  a few days or more
# 6030               Bedrooms close to Wanda Metropolitano         no response
# 5873          Wanda Metropolitano Final Champions League         no response
# 17720     Beatifull apartement in the center of the city         no response
# 11511                    Comuna en las afueras de Madrid         no response
#
#       host_is_superhost                host_verifications  \
# 3305                  f                ['email', 'phone']
# 6359                  f                ['email', 'phone']
# 12021                 f                ['email', 'phone']
# 5769                  f                ['email', 'phone']
# 6165                  f                ['email', 'phone']
# 6307                  f                ['email', 'phone']
# 6030                  f                ['email', 'phone']
# 5873                  f                ['email', 'phone']
# 17720                 f                ['email', 'phone']
# 11511                 f  ['email', 'phone', 'work_email']
#
#       host_has_profile_pic host_identity_verified neighbourhood_cleansed  \
# 3305                     t                      f                  Rosas
# 6359                     t                      t                 Hellín
# 12021                    t                      t                  Arcos
# 5769                     t                      t                  Rosas
# 6165                     t                      f                  Arcos
# 6307                     t                      t                  Arcos
# 6030                     t                      f                  Rosas
# 5873                     t                      t                  Rosas
# 17720                    t                      t                  Rejas
# 11511                    t                      t               Simancas
#
#                            property_type        room_type  \
# 3305                Private room in home     Private room
# 6359         Private room in rental unit     Private room
# 12021  Private room in bed and breakfast     Private room
# 5769                Private room in home     Private room
# 6165                Private room in home     Private room
# 6307                Private room in home     Private room
# 6030                Private room in home     Private room
# 5873               Private room in condo     Private room
# 17720                        Entire home  Entire home/apt
# 11511         Shared room in rental unit      Shared room
#
#                                                amenities has_availability  \
# 3305   ["BBQ grill", "Dishwasher", "Pool", "Gym", "Br...              yes
# 6359   ["Private living room", "Hangers", "Heating", ...              yes
# 12021                ["Wifi", "Kitchen", "TV", "Washer"]              yes
# 5769   ["Hangers", "Breakfast", "Heating", "Wifi", "H...              yes
# 6165   ["Exterior security cameras on property", "Bre...               no
# 6307   ["Hangers", "First aid kit", "Heating", "Wifi"...              yes
# 6030   ["Hangers", "Exterior security cameras on prop...              yes
# 5873   ["Hangers", "First aid kit", "Heating", "Wifi"...              yes
# 17720                                           ["Wifi"]              yes
# 11511                                                 []              yes
#
#       license instant_bookable neighbourhood_group    host_id  \
# 3305       no                t            San Blas   11086450
# 6359       no                t            San Blas   78241549
# 12021      no                f            San Blas  144457564
# 5769       no                t            San Blas  231479865
# 6165       no                f            San Blas  263474389
# 6307       no                t            San Blas  124425621
# 6030       no                t            San Blas   49642755
# 5873       no                t            San Blas  261135831
# 17720      no                t            San Blas  528957573
# 11511      no                t            San Blas  369250484
#
#                        host_since  host_response_rate  host_acceptance_rate  \
# 3305   2014-01-07 00:00:00.000000                 0.0                  75.0
# 6359   2016-06-17 00:00:00.000000                 0.0                  86.0
# 12021  2017-08-05 00:00:00.000000                 0.0                  80.0
# 5769   2018-12-19 00:00:00.000000                 0.0                  75.0
# 6165   2019-05-22 00:00:00.000000                 0.0                  80.0
# 6307   2017-04-05 00:00:00.000000                 0.0                  80.0
# 6030   2015-11-22 00:00:00.000000                 0.0                  75.0
# 5873   2019-05-11 00:00:00.000000                 0.0                  75.0
# 17720  2023-07-31 00:00:00.000000                 0.0                 100.0
# 11511  2020-09-25 00:00:00.000000                 0.0                  85.0
#
#        host_listings_count  host_total_listings_count   latitude  longitude  \
# 3305                   1.0                        1.0  40.430030  -3.599750
# 6359                   1.0                        1.0  40.431270  -3.612340
# 12021                  1.0                        1.0  40.423490  -3.620860
# 5769                   1.0                        3.0  40.429030  -3.607640
# 6165                   1.0                        2.0  40.419200  -3.612290
# 6307                   2.0                        3.0  40.426580  -3.611960
# 6030                   2.0                        2.0  40.425620  -3.604900
# 5873                   3.0                        3.0  40.430820  -3.604610
# 17720                  3.0                        6.0  40.446989  -3.596043
# 11511                  1.0                        1.0  40.438370  -3.619480
#
#        accommodates  bathrooms  bedrooms  beds  price  minimum_nights  \
# 3305              3        1.0       2.0   3.0    700               2
# 6359              5        1.5       2.0   2.0   1050               1
# 12021             3        1.0       1.0   2.0   1000               2
# 5769              3        2.0       2.0   2.0    950               1
# 6165             10        4.0       5.0   4.0    469               1
# 6307              3        2.0       2.0   3.0    500               1
# 6030              3        1.5       2.0   2.0    700               1
# 5873              3        2.0       2.0   2.0    508               1
# 17720             1        1.0       1.0   1.0   1001               1
# 11511             1        0.5       1.0   1.0   1000               1
#
#        maximum_nights  availability_30  availability_60  availability_90  \
# 3305               30               30               60               90
# 6359                3               30               60               90
# 12021               3               29               59               89
# 5769                3               30               60               90
# 6165                3                0                0                0
# 6307                3               30               60               90
# 6030                4               28               58               88
# 5873                1                0                0                0
# 17720             365               30               60               90
# 11511             365               30               60               90
#
#        availability_365  number_of_reviews  number_of_reviews_ltm  \
# 3305                365                  0                      0
# 6359                365                  0                      0
# 12021                89                  1                      0
# 5769                365                  1                      0
# 6165                  0                  0                      0
# 6307                365                  0                      0
# 6030                 88                  0                      0
# 5873                  0                  0                      0
# 17720               270                  0                      0
# 11511               365                  0                      0
#
#        number_of_reviews_l30d                first_review  \
# 3305                        0  2014-01-07 00:00:00.000000
# 6359                        0  2016-06-17 00:00:00.000000
# 12021                       0  2022-09-28 00:00:00.000000
# 5769                        0  2019-06-02 00:00:00.000000
# 6165                        0  2019-05-22 00:00:00.000000
# 6307                        0  2017-04-05 00:00:00.000000
# 6030                        0  2015-11-22 00:00:00.000000
# 5873                        0  2019-05-11 00:00:00.000000
# 17720                       0  2023-07-31 00:00:00.000000
# 11511                       0  2020-09-25 00:00:00.000000
#
#                       last_review  review_scores_rating  \
# 3305   2014-01-07 00:00:00.000000                   0.0
# 6359   2016-06-17 00:00:00.000000                   0.0
# 12021  2022-09-28 00:00:00.000000                   5.0
# 5769   2019-06-02 00:00:00.000000                   5.0
# 6165   2019-05-22 00:00:00.000000                   0.0
# 6307   2017-04-05 00:00:00.000000                   0.0
# 6030   2015-11-22 00:00:00.000000                   0.0
# 5873   2019-05-11 00:00:00.000000                   0.0
# 17720  2023-07-31 00:00:00.000000                   0.0
# 11511  2020-09-25 00:00:00.000000                   0.0
#
#        review_scores_accuracy  review_scores_cleanliness  \
# 3305                      0.0                        0.0
# 6359                      0.0                        0.0
# 12021                     5.0                        5.0
# 5769                      5.0                        5.0
# 6165                      0.0                        0.0
# 6307                      0.0                        0.0
# 6030                      0.0                        0.0
# 5873                      0.0                        0.0
# 17720                     0.0                        0.0
# 11511                     0.0                        0.0
#
#        review_scores_checkin  review_scores_communication  \
# 3305                     0.0                          0.0
# 6359                     0.0                          0.0
# 12021                    5.0                          5.0
# 5769                     5.0                          5.0
# 6165                     0.0                          0.0
# 6307                     0.0                          0.0
# 6030                     0.0                          0.0
# 5873                     0.0                          0.0
# 17720                    0.0                          0.0
# 11511                    0.0                          0.0
#
#        review_scores_location  review_scores_value  \
# 3305                      0.0                  0.0
# 6359                      0.0                  0.0
# 12021                     5.0                  5.0
# 5769                      5.0                  5.0
# 6165                      0.0                  0.0
# 6307                      0.0                  0.0
# 6030                      0.0                  0.0
# 5873                      0.0                  0.0
# 17720                     0.0                  0.0
# 11511                     0.0                  0.0
#
#        calculated_host_listings_count  \
# 3305                                1
# 6359                                1
# 12021                               1
# 5769                                1
# 6165                                1
# 6307                                1
# 6030                                2
# 5873                                1
# 17720                               1
# 11511                               1
#
#        calculated_host_listings_count_entire_homes  \
# 3305                                             0
# 6359                                             0
# 12021                                            0
# 5769                                             0
# 6165                                             0
# 6307                                             0
# 6030                                             0
# 5873                                             0
# 17720                                            1
# 11511                                            0
#
#        calculated_host_listings_count_private_rooms  \
# 3305                                              1
# 6359                                              1
# 12021                                             1
# 5769                                              1
# 6165                                              1
# 6307                                              1
# 6030                                              2
# 5873                                              1
# 17720                                             0
# 11511                                             0
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month  \
# 3305                                             0               0.00
# 6359                                             0               0.00
# 12021                                            0               0.04
# 5769                                             0               0.01
# 6165                                             0               0.00
# 6307                                             0               0.00
# 6030                                             0               0.00
# 5873                                             0               0.00
# 17720                                            0               0.00
# 11511                                            1               0.00
#
#        precio_m2  precio_total  ocupacion    bedrooms_disc accommodates_disc  \
# 3305        2996       2099.62          0           02_Dos               0-3
# 6359        2996       2099.62          0           02_Dos              4-16
# 12021       2996       1999.62         75           01_Una               0-3
# 5769        2996       1899.62          0           02_Dos               0-3
# 6165        2996       1875.62        100  04_Cuatro o mas              4-16
# 6307        2996       1499.62          0           02_Dos               0-3
# 6030        2996       1399.62         75           02_Dos               0-3
# 5873        2996       1015.62        100           02_Dos               0-3
# 17720       2996       1001.00         26           01_Una               0-3
# 11511       2996       1000.00          0           01_Una               0-3
#
#       beds_disc number_of_reviews_disc   m2  precio_compra   pdi_sol  \
# 3305          3                    1-4   70       167776.0  8.895150
# 6359          3                    1-4   70       167776.0  7.873067
# 12021         3                    1-4   50       119840.0  7.024499
# 5769          3                    1-4   70       167776.0  8.217940
# 6165       3-19                    1-4  150       359520.0  7.714952
# 6307          3                    1-4   70       167776.0  7.814783
# 6030          3                    1-4   70       167776.0  8.393914
# 5873          3                    1-4   70       167776.0  8.505350
# 17720         1                    1-4   50       119840.0  9.687539
# 11511         1                    1-4   50       119840.0  7.497144
#
#        pisos_rentables
# 3305                 0
# 6359                 0
# 12021                1
# 5769                 0
# 6165                 1
# 6307                 0
# 6030                 1
# 5873                 1
# 17720                1
# 11511                0

# %% [markdown]
# Vemos que hay precios superiores a 2000 euros que por la zona entendemos que son datos atípicos de alquileres pero, por conocimiento del negocio y de la ciudad, sabemos que el estadio del Atlético de Madrid está allí y esas noches tan caras es muy probable que sean las noches de los partidos importantes como los de la Champions League. Lo cual es un insight interesante:
#
# **Insight 1: pueden existir inmuebles con un valor regular residual pero con alto valor en momentos puntuales por acontenicimientos deportivos o espectáculos**
#
# ¿Tendría sentido generar un producto de alquiler que consista en alquilar de forma "normal" a un precio inferior al mercado con la condición de que el inquilino deje el piso libre para alquilarlo "turísticamente" en fechas señaladas?

# %% [markdown]
# En el resto no hay sorpresas, con distritos como Salamanca, Centro o Chanmartín a la cabeza.
#
# Pero por ejemplo vemos que la diferencia de precio media entre Retiro y Tetuán es muy baja.
#
# Esto nos lleva a comparar el precio medio por distrito con el precio medio de compra también por distrito.

# %%
temp = df.groupby('neighbourhood_group')[['precio_total','precio_compra']].median()
temp
# Out:
#                      precio_total  precio_compra
# neighbourhood_group
# Arganzuela                  85.00       194000.0
# Barajas                     79.00       147440.0
# Carabanchel                 65.00       108480.0
# Centro                     111.00       246800.0
# Chamartín                  109.00       251400.0
# Chamberí                   104.00       266600.0
# Ciudad Lineal               78.00       147040.0
# Fuencarral                  82.50       161520.0
# Hortaleza                   86.00       174720.0
# Latina                      70.00       110880.0
# Moncloa                    101.00       195040.0
# Moratalaz                   47.50       125440.0
# Puente de Vallecas          65.50        94680.0
# Retiro                      98.00       221960.0
# Salamanca                  120.00       313840.0
# San Blas                    89.81       119840.0
# Tetuán                      92.00       181440.0
# Usera                       59.00        99880.0
# Vicálvaro                   51.00       117880.0
# Villa de Vallecas           60.00       113200.0
# Villaverde                  60.00        82800.0

# %%
plt.figure(figsize = (16,8))
sns.scatterplot(data = temp, x = 'precio_compra', y = 'precio_total')
#Ponemos las etiquetas
for cada in range(0,temp.shape[0]):
    plt.text(temp.precio_compra.iloc[cada], temp.precio_total.iloc[cada], temp.index[cada])

# %% [markdown]
# Existe una clara correlación entre el precio de compra en cada distrito y el precio que podremos cobrar. Claramente se perciben tres clusters de bajo-bajo, medio-medio y alto-alto, y la excepción de San Blas que ya sabemos por qué es.
#
# Por tanto, como era esperable no hay a priori ningún "chollo" claro a este nivel, así que vamos a repetir el análisis a nivel de barrio a ver si identificamos algo.

# %%
temp = df.groupby('neighbourhood_cleansed')[['precio_total','precio_compra']].median()
temp
# Out:
#                         precio_total  precio_compra
# neighbourhood_cleansed
# Abrantes                       57.00       108480.0
# Acacias                        77.62       194000.0
# Adelfas                        90.00       221960.0
# Aeropuerto                     56.50       147440.0
# Aguilas                        50.00       110880.0
# ...                              ...            ...
# Valverde                       81.00       161520.0
# Ventas                         64.00       147040.0
# Vinateros                      32.50       125440.0
# Vista Alegre                   59.00       108480.0
# Zofío                          54.50        99880.0
#
# [127 rows x 2 columns]

# %%
plt.figure(figsize = (16,20))
sns.scatterplot(data = temp, x = 'precio_compra', y = 'precio_total')
#Ponemos las etiquetas
for cada in range(0,temp.shape[0]):
    plt.text(temp.precio_compra.iloc[cada], temp.precio_total.iloc[cada], temp.index[cada])

# %% [markdown]
# A este nivel ya vemos más cosas:
#
# * 1 barrio que sobresale de San Blas
# * Dentro de cada grupo de bajo-medio-alto sí podemos empezar a separarar
#     * Bajo <150K: Amposta
#     * Medio 150K-250K: Arguelles y Cortés
#     * Medio-alto 250K-350K: Almagro
#     * Alto >350K: Castellana
#
# **Insight 2: Existen ciertos barrios que apriori pueden maximizar la relación ingresos-coste y además podemos segmentarlo por el tipo calidad del inmueble en el que nos interes invertir**

# %%
df.loc[df.neighbourhood_cleansed.isin(['Amposta']),'neighbourhood_group'].unique()
# Out:
# array(['San Blas'], dtype=object)

# %% [markdown]
# **¿Qué factores (a parte de la localización determinan el precio del alquiler?**

# %% [markdown]
# Para responder a esta pregunta podemos construir un minicubo, ya que hemos discretizado nuestras variables de análisis.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25873 entries, 0 to 25872
# Data columns (total 63 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   index                                         25873 non-null  int64
#  1   id                                            25873 non-null  int64
#  2   name                                          25873 non-null  object
#  3   host_response_time                            25873 non-null  object
#  4   host_is_superhost                             25873 non-null  object
#  5   host_verifications                            25873 non-null  object
#  6   host_has_profile_pic                          25873 non-null  object
#  7   host_identity_verified                        25873 non-null  object
#  8   neighbourhood_cleansed                        25873 non-null  object
#  9   property_type                                 25873 non-null  object
#  10  room_type                                     25873 non-null  object
#  11  amenities                                     25873 non-null  object
#  12  has_availability                              25873 non-null  object
#  13  license                                       25873 non-null  object
#  14  instant_bookable                              25873 non-null  object
#  15  neighbourhood_group                           25873 non-null  object
#  16  host_id                                       25873 non-null  int64
#  17  host_since                                    25873 non-null  object
#  18  host_response_rate                            25873 non-null  float64
#  19  host_acceptance_rate                          25873 non-null  float64
#  20  host_listings_count                           25873 non-null  float64
#  21  host_total_listings_count                     25873 non-null  float64
#  22  latitude                                      25873 non-null  float64
#  23  longitude                                     25873 non-null  float64
#  24  accommodates                                  25873 non-null  int64
#  25  bathrooms                                     25873 non-null  float64
#  26  bedrooms                                      25873 non-null  float64
#  27  beds                                          25873 non-null  float64
#  28  price                                         25873 non-null  int64
#  29  minimum_nights                                25873 non-null  int64
#  30  maximum_nights                                25873 non-null  int64
#  31  availability_30                               25873 non-null  int64
#  32  availability_60                               25873 non-null  int64
#  33  availability_90                               25873 non-null  int64
#  34  availability_365                              25873 non-null  int64
#  35  number_of_reviews                             25873 non-null  int64
#  36  number_of_reviews_ltm                         25873 non-null  int64
#  37  number_of_reviews_l30d                        25873 non-null  int64
#  38  first_review                                  25873 non-null  object
#  39  last_review                                   25873 non-null  object
#  40  review_scores_rating                          25873 non-null  float64
#  41  review_scores_accuracy                        25873 non-null  float64
#  42  review_scores_cleanliness                     25873 non-null  float64
#  43  review_scores_checkin                         25873 non-null  float64
#  44  review_scores_communication                   25873 non-null  float64
#  45  review_scores_location                        25873 non-null  float64
#  46  review_scores_value                           25873 non-null  float64
#  47  calculated_host_listings_count                25873 non-null  int64
#  48  calculated_host_listings_count_entire_homes   25873 non-null  int64
#  49  calculated_host_listings_count_private_rooms  25873 non-null  int64
#  50  calculated_host_listings_count_shared_rooms   25873 non-null  int64
#  51  reviews_per_month                             25873 non-null  float64
#  52  precio_m2                                     25873 non-null  int64
#  53  precio_total                                  25873 non-null  float64
#  54  ocupacion                                     25873 non-null  int64
#  55  bedrooms_disc                                 25873 non-null  object
#  56  accommodates_disc                             25873 non-null  object
#  57  beds_disc                                     25873 non-null  object
#  58  number_of_reviews_disc                        25873 non-null  object
#  59  m2                                            25873 non-null  int64
#  60  precio_compra                                 25873 non-null  float64
#  61  pdi_sol                                       25873 non-null  float64
#  62  pisos_rentables                               25873 non-null  int64
# dtypes: float64(20), int64(22), object(21)
# memory usage: 12.4+ MB

# %%
#Paso 1: Seleccionar qué variables serán la métricas y cuales las dimensiones
metricas = ['precio_total','precio_compra']
dimensiones = ['bedrooms_disc','accommodates_disc','beds_disc','number_of_reviews_disc']

minicubo_precio = df[dimensiones + metricas]
minicubo_precio
# Out:
#       bedrooms_disc accommodates_disc beds_disc number_of_reviews_disc  \
# 0            01_Una               0-3         1                   5-71
# 1            01_Una               0-3         1                71-1136
# 2            01_Una               0-3         1                    1-4
# 3            01_Una               0-3         3                   5-71
# 4            01_Una                 4         3                71-1136
# ...             ...               ...       ...                    ...
# 25868        01_Una               0-3         1                    1-4
# 25869        01_Una                 4         3                    1-4
# 25870        01_Una               0-3         1                    1-4
# 25871        01_Una               0-3         3                    1-4
# 25872        01_Una               0-3         1                    1-4
#
#        precio_total  precio_compra
# 0             31.00       110880.0
# 1            149.00       246800.0
# 2             92.00       246800.0
# 3            124.00       246800.0
# 4            137.62       246800.0
# ...             ...            ...
# 25868         85.00       147040.0
# 25869        258.00       110880.0
# 25870         20.00       246800.0
# 25871        258.00       110880.0
# 25872        161.00       194000.0
#
# [25873 rows x 6 columns]

# %%
#Paso 2: pasar a transaccional las dimensiones
minicubo_precio = minicubo_precio.melt(id_vars=['precio_total','precio_compra'])
minicubo_precio
# Out:
#         precio_total  precio_compra                variable   value
# 0              31.00       110880.0           bedrooms_disc  01_Una
# 1             149.00       246800.0           bedrooms_disc  01_Una
# 2              92.00       246800.0           bedrooms_disc  01_Una
# 3             124.00       246800.0           bedrooms_disc  01_Una
# 4             137.62       246800.0           bedrooms_disc  01_Una
# ...              ...            ...                     ...     ...
# 103487         85.00       147040.0  number_of_reviews_disc     1-4
# 103488        258.00       110880.0  number_of_reviews_disc     1-4
# 103489         20.00       246800.0  number_of_reviews_disc     1-4
# 103490        258.00       110880.0  number_of_reviews_disc     1-4
# 103491        161.00       194000.0  number_of_reviews_disc     1-4
#
# [103492 rows x 4 columns]

# %%
#Paso 3: Agregar las métricas por "variable" y "valor" con las funciones deseadas
minicubo_precio = minicubo_precio.groupby(['variable','value'])[['precio_total','precio_compra']].agg('median')
minicubo_precio
# Out:
#                                         precio_total  precio_compra
# variable               value
# accommodates_disc      0-3                     80.00       201120.0
#                        4                      121.00       246800.0
#                        4-16                   174.00       345520.0
# bedrooms_disc          00_Estudio              82.00       197440.0
#                        01_Una                  86.00       246800.0
#                        02_Dos                 136.50       345520.0
#                        03_Tres                180.00       444240.0
#                        04_Cuatro o mas        250.00       592320.0
# beds_disc              1                       74.00       197440.0
#                        3                      122.31       246800.0
#                        3-19                   190.00       359520.0
# number_of_reviews_disc 1-4                     99.00       246800.0
#                        5-71                   100.00       246800.0
#                        71-1136                100.00       246800.0

# %% [markdown]
# Sobre el minicubo vamos analizando cada variable.

# %%
minicubo_precio.loc['bedrooms_disc']
# Out:
#                  precio_total  precio_compra
# value
# 00_Estudio               82.0       197440.0
# 01_Una                   86.0       246800.0
# 02_Dos                  136.5       345520.0
# 03_Tres                 180.0       444240.0
# 04_Cuatro o mas         250.0       592320.0

# %%
f, ax = plt.subplots()
ax.plot(minicubo_precio.loc['bedrooms_disc'].precio_total)
ax2 = ax.twinx()
ax2.plot(minicubo_precio.loc['bedrooms_disc'].precio_compra,color = 'green');

# %% [markdown]
# En cuanto al número de habitaciones entre cero y una habitación, el precio_compra casi no varia pero si aumenta el precio_total por lo que sería mas rentable
#
# Parte de este efecto puede ser artificial, ya que usamos el número de habitaciones para calcular el precio total como el precio de compra.

# %%
minicubo_precio.loc['beds_disc']
# Out:
#        precio_total  precio_compra
# value
# 1             74.00       197440.0
# 3            122.31       246800.0
# 3-19         190.00       359520.0

# %%
f, ax = plt.subplots()
ax.plot(minicubo_precio.loc['beds_disc'].precio_total)
ax2 = ax.twinx()
ax2.plot(minicubo_precio.loc['beds_disc'].precio_compra,color = 'green');

# %% [markdown]
# En cuanto al número de camas sí hay una conclusión:
#
# **Insight 3: el número de camas a evitar es 2**. O bien ponemos una cama o intentamos meter todas las posibles.
#
# Dado que no había este efecto en el número de habitaciones podría ser que los propietarios estén intentando meter muchas más camas que habitaciones para maximizar el ingreso
#
# Veámoslo por ejemplo con los pisos de una habitación:

# %%
df[df.bedrooms == 1].groupby('beds').precio_total.median().plot();

# %% [markdown]
# Efectivamente aquí hay algo, ya que figura que para pisos de una habitación hay gente que está metiendo hasta doce de camas
#
# Sería un tema a explorar con más detalle y comentar con alguien que conozca el negocio por si hubiera algo que aportar, pero la conclusión es que hay propietarios que buscan maximizar el beneficio metiendo muchas camas por habitación
#
# Vamos a ver unos ejemplos:

# %%
df.loc[(df.bedrooms == 1) & (df.beds > 6)]
# Out:
#        index                   id  \
# 2120    2120             15428073
# 10321  10321   544815531002663097
# 13098  13098   784862856028711383
# 16278  16278   951931255884882441
# 17066  17066   996129561563914923
# 17154  17154   998269085402388662
# 17361  17361  1011554774276353687
# 17873  17873  1033327900604883402
# 21925  21925  1186929367473323308
# 22063  22063  1188554103725517113
# 23533  23533  1241518117004114298
#
#                                                     name host_response_time  \
# 2120          HELLENHOST: Cozy Loft in Gran Vía - Madrid     within an hour
# 10321                 PUERTA DEL SOL PERFECTO PARA GRUPO     within an hour
# 13098  Paseo de la Castellana. 10’ del Santiago Bernabeu     within an hour
# 16278              Cama en habitación compartida 6 camas     within an hour
# 17066              Cama en habitación compartida 6 camas     within an hour
# 17154           2 Camas en habitación compartida 6 camas     within an hour
# 17361  5 Camas en hab. compartida-baño privado, 6 lit...     within an hour
# 17873           2 Camas en habitación compartida 6 camas     within an hour
# 21925              Cama en habitación compartida 6 camas     within an hour
# 22063              Cama en habitación compartida 6 camas     within an hour
# 23533                     11-Hab compartida masculina X8     within an hour
#
#       host_is_superhost       host_verifications host_has_profile_pic  \
# 2120                  f  ['phone', 'work_email']                    t
# 10321                 f       ['email', 'phone']                    f
# 13098                 t       ['email', 'phone']                    t
# 16278                 f       ['email', 'phone']                    t
# 17066                 f       ['email', 'phone']                    t
# 17154                 f       ['email', 'phone']                    t
# 17361                 f       ['email', 'phone']                    t
# 17873                 f       ['email', 'phone']                    t
# 21925                 f       ['email', 'phone']                    t
# 22063                 f       ['email', 'phone']                    t
# 23533                 f       ['email', 'phone']                    t
#
#       host_identity_verified neighbourhood_cleansed  \
# 2120                       t            Universidad
# 10321                      t                 Cortes
# 13098                      t             Berruguete
# 16278                      t            Embajadores
# 17066                      t            Embajadores
# 17154                      t            Embajadores
# 17361                      t            Universidad
# 17873                      t            Embajadores
# 21925                      t            Embajadores
# 22063                      t            Embajadores
# 23533                      t                 Cortes
#
#                           property_type        room_type  \
# 2120                 Entire rental unit  Entire home/apt
# 10321                Entire rental unit  Entire home/apt
# 13098                Entire rental unit  Entire home/apt
# 16278        Shared room in rental unit      Shared room
# 17066        Shared room in rental unit      Shared room
# 17154        Shared room in rental unit      Shared room
# 17361        Shared room in rental unit      Shared room
# 17873       Private room in rental unit     Private room
# 21925        Shared room in rental unit      Shared room
# 22063        Shared room in rental unit      Shared room
# 23533  Shared room in bed and breakfast      Shared room
#
#                                                amenities has_availability  \
# 2120   ["City skyline view", "First aid kit", "Wifi",...              yes
# 10321  ["Bidet", "Wifi", "Clothing storage: closet", ...              yes
# 13098  ["Wifi", "Clothing storage: closet", "AC - spl...              yes
# 16278  ["Smoke alarm", "First aid kit", "Wifi", "Self...              yes
# 17066  ["First aid kit", "Wifi", "Kitchen", "Essentia...              yes
# 17154  ["First aid kit", "Wifi", "Kitchen", "Essentia...              yes
# 17361  ["First aid kit", "Wifi", "Kitchenette", "Esse...              yes
# 17873  ["First aid kit", "Wifi", "Kitchen", "Hot wate...              yes
# 21925  ["Smoke alarm", "First aid kit", "Wifi", "Kitc...              yes
# 22063                          ["Wifi", "Kitchen", "TV"]              yes
# 23533  ["Wifi", "Smoking allowed", "Kitchen", "TV", "...              yes
#
#       license instant_bookable neighbourhood_group    host_id  \
# 2120      yes                t              Centro   32420211
# 10321      no                t              Centro  441464755
# 13098      no                t              Tetuán  402837283
# 16278      no                f              Centro  529015349
# 17066      no                f              Centro  529015349
# 17154      no                f              Centro  529015349
# 17361      no                t              Centro  493916828
# 17873      no                f              Centro  529015349
# 21925      no                f              Centro  529015349
# 22063      no                f              Centro  529015349
# 23533      no                t              Centro  286514428
#
#                        host_since  host_response_rate  host_acceptance_rate  \
# 2120   2015-05-02 00:00:00.000000               100.0                 100.0
# 10321  2022-01-21 00:00:00.000000                93.0                 100.0
# 13098  2021-05-22 00:00:00.000000               100.0                 100.0
# 16278  2023-07-31 00:00:00.000000               100.0                  99.0
# 17066  2023-07-31 00:00:00.000000               100.0                  99.0
# 17154  2023-07-31 00:00:00.000000               100.0                  99.0
# 17361  2023-01-02 00:00:00.000000                93.0                 100.0
# 17873  2023-07-31 00:00:00.000000               100.0                  99.0
# 21925  2023-07-31 00:00:00.000000               100.0                  99.0
# 22063  2023-07-31 00:00:00.000000               100.0                  99.0
# 23533  2019-08-16 00:00:00.000000               100.0                  83.0
#
#        host_listings_count  host_total_listings_count   latitude  longitude  \
# 2120                   4.0                        5.0  40.421257  -3.706301
# 10321                  1.0                        1.0  40.415480  -3.700610
# 13098                 11.0                       13.0  40.460340  -3.700470
# 16278                 15.0                       23.0  40.411811  -3.704862
# 17066                 15.0                       23.0  40.411076  -3.705688
# 17154                 15.0                       23.0  40.411811  -3.704862
# 17361                 31.0                       50.0  40.422597  -3.704498
# 17873                 15.0                       23.0  40.411090  -3.704320
# 21925                 15.0                       23.0  40.411059  -3.703784
# 22063                 15.0                       23.0  40.412862  -3.705277
# 23533                  7.0                        9.0  40.416310  -3.695540
#
#        accommodates  bathrooms  bedrooms  beds  price  minimum_nights  \
# 2120              6        1.0       1.0   7.0    226               1
# 10321             8        1.0       1.0   8.0    145               2
# 13098             6        1.0       1.0   7.0     63               1
# 16278             1        3.0       1.0   8.0     24               1
# 17066             1        3.0       1.0   8.0     24               1
# 17154             2        3.0       1.0   8.0     49               1
# 17361             5        2.5       1.0  12.0    137               1
# 17873             2        3.0       1.0   8.0     49               1
# 21925             1        0.5       1.0   8.0     21               1
# 22063             1        0.5       1.0   8.0     26               1
# 23533             1        2.0       1.0   8.0     43               1
#
#        maximum_nights  availability_30  availability_60  availability_90  \
# 2120             1125               20               45               68
# 10321            1125                9               20               37
# 13098             120               13               36               36
# 16278             365               13               43               43
# 17066             365                8                8               20
# 17154             365               12               36               66
# 17361             365                0                0                0
# 17873             365                5                5                5
# 21925             365                8               21               46
# 22063             365               13               43               73
# 23533             365               30               60               90
#
#        availability_365  number_of_reviews  number_of_reviews_ltm  \
# 2120                259                100                      2
# 10321               111                123                     36
# 13098                36                 72                     37
# 16278               289                 78                     63
# 17066               282                 72                     62
# 17154               341                 46                     41
# 17361               266                  1                      0
# 17873               190                 29                     29
# 21925               311                 27                     27
# 22063               348                 14                     14
# 23533               365                  5                      5
#
#        number_of_reviews_l30d                first_review  \
# 2120                        0  2016-11-19 00:00:00.000000
# 10321                       1  2022-02-06 00:00:00.000000
# 13098                       3  2023-02-19 00:00:00.000000
# 16278                       2  2023-08-09 00:00:00.000000
# 17066                       4  2023-10-11 00:00:00.000000
# 17154                       5  2023-10-29 00:00:00.000000
# 17361                       0  2023-11-12 00:00:00.000000
# 17873                       0  2024-01-23 00:00:00.000000
# 21925                       8  2024-07-04 00:00:00.000000
# 22063                       2  2024-06-30 00:00:00.000000
# 23533                       1  2024-10-09 00:00:00.000000
#
#                       last_review  review_scores_rating  \
# 2120   2024-05-26 00:00:00.000000                  4.76
# 10321  2024-11-24 00:00:00.000000                  4.60
# 13098  2024-12-08 00:00:00.000000                  4.85
# 16278  2024-11-16 00:00:00.000000                  4.53
# 17066  2024-12-01 00:00:00.000000                  4.69
# 17154  2024-12-01 00:00:00.000000                  4.54
# 17361  2023-11-12 00:00:00.000000                  4.00
# 17873  2024-10-20 00:00:00.000000                  4.62
# 21925  2024-12-09 00:00:00.000000                  4.70
# 22063  2024-11-24 00:00:00.000000                  4.64
# 23533  2024-12-08 00:00:00.000000                  4.00
#
#        review_scores_accuracy  review_scores_cleanliness  \
# 2120                     4.87                       4.92
# 10321                    4.66                       4.59
# 13098                    4.86                       4.79
# 16278                    4.72                       4.61
# 17066                    4.81                       4.68
# 17154                    4.85                       4.52
# 17361                    4.00                       3.00
# 17873                    4.45                       4.69
# 21925                    4.81                       4.85
# 22063                    4.57                       4.50
# 23533                    4.20                       3.80
#
#        review_scores_checkin  review_scores_communication  \
# 2120                    4.81                         4.88
# 10321                   4.76                         4.69
# 13098                   4.96                         4.96
# 16278                   4.69                         4.79
# 17066                   4.83                         4.83
# 17154                   4.87                         4.85
# 17361                   5.00                         3.00
# 17873                   4.59                         4.79
# 21925                   4.89                         4.85
# 22063                   4.86                         4.93
# 23533                   4.20                         4.20
#
#        review_scores_location  review_scores_value  \
# 2120                     4.97                 4.74
# 10321                    4.80                 4.59
# 13098                    4.93                 4.79
# 16278                    4.72                 4.67
# 17066                    4.86                 4.76
# 17154                    4.80                 4.67
# 17361                    5.00                 4.00
# 17873                    4.86                 4.52
# 21925                    4.89                 4.74
# 22063                    4.86                 4.50
# 23533                    4.20                 4.20
#
#        calculated_host_listings_count  \
# 2120                                4
# 10321                               1
# 13098                               6
# 16278                              15
# 17066                              15
# 17154                              15
# 17361                              31
# 17873                              15
# 21925                              15
# 22063                              15
# 23533                               7
#
#        calculated_host_listings_count_entire_homes  \
# 2120                                             4
# 10321                                            1
# 13098                                            6
# 16278                                            0
# 17066                                            0
# 17154                                            0
# 17361                                            0
# 17873                                            0
# 21925                                            0
# 22063                                            0
# 23533                                            0
#
#        calculated_host_listings_count_private_rooms  \
# 2120                                              0
# 10321                                             0
# 13098                                             0
# 16278                                             4
# 17066                                             4
# 17154                                             4
# 17361                                             5
# 17873                                             4
# 21925                                             4
# 22063                                             4
# 23533                                             0
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month  \
# 2120                                             0               1.02
# 10321                                            0               3.54
# 13098                                            0               3.26
# 16278                                           11               4.76
# 17066                                           11               5.03
# 17154                                           11               3.36
# 17361                                           26               0.08
# 17873                                           11               2.68
# 21925                                           11               5.00
# 22063                                           11               2.53
# 23533                                            7               2.31
#
#        precio_m2  precio_total  ocupacion bedrooms_disc accommodates_disc  \
# 2120        6170        226.00         29        01_Una              4-16
# 10321       6170        145.00         69        01_Una              4-16
# 13098       4536         63.00         90        01_Una              4-16
# 16278       6170        191.44         20        01_Una               0-3
# 17066       6170        191.44         22        01_Una               0-3
# 17154       6170        391.44          6        01_Una               0-3
# 17361       6170       1643.44         27        01_Una              4-16
# 17873       6170        391.62         47        01_Una               0-3
# 21925       6170        167.44         14        01_Una               0-3
# 22063       6170        207.44          4        01_Una               0-3
# 23533       6170        343.44          0        01_Una               0-3
#
#       beds_disc number_of_reviews_disc  m2  precio_compra   pdi_sol  \
# 2120       3-19                71-1136  50       246800.0  0.562764
# 10321      3-19                71-1136  50       246800.0  0.269550
# 13098      3-19                71-1136  50       181440.0  4.856901
# 16278      3-19                71-1136  50       246800.0  0.561938
# 17066      3-19                71-1136  50       246800.0  0.659407
# 17154      3-19                   5-71  50       246800.0  0.561938
# 17361      3-19                    1-4  50       246800.0  0.660175
# 17873      3-19                   5-71  50       246800.0  0.632554
# 21925      3-19                   5-71  50       246800.0  0.631630
# 22063      3-19                   5-71  50       246800.0  0.460222
# 23533      3-19                    1-4  50       246800.0  0.662045
#
#        pisos_rentables
# 2120                 1
# 10321                1
# 13098                1
# 16278                1
# 17066                1
# 17154                0
# 17361                1
# 17873                1
# 21925                0
# 22063                0
# 23533                0

# %% [markdown]
# Vamos a analizar ahora por el número de huéspedes que aceptan

# %%
minicubo_precio.loc['accommodates_disc']
# Out:
#        precio_total  precio_compra
# value
# 0-3            80.0       201120.0
# 4             121.0       246800.0
# 4-16          174.0       345520.0

# %%
f, ax = plt.subplots()
ax.plot(minicubo_precio.loc['accommodates_disc'].precio_total)
ax2 = ax.twinx()
ax2.plot(minicubo_precio.loc['accommodates_disc'].precio_compra,color = 'green');

# %% [markdown]
# **Insight 4: el número óptimo de huéspedes está en 4, ya el precio de los inmuebles no varia demasiado hasta esos ocupantes pero, a partir de 4 el piso necesita ser mayor y el precio de compra se incrementa bastante**

# %% [markdown]
# Por último vamos a analizar la variable que hemos construído de cercanía a un punto de interés para ver si tiene efecto sobre el precio de las habitaciones.
#
# En este caso como hemos construído la distancia a la Puerta del Sol vamos a evaluar solo los distritos para lo que esto puede ser relevante, es decir los más céntricos pero se podrían construir tantas variables con los puntos de interés como fuera necesario repitiendo el análisis para cada una
#
# Para ello primero vamos a calcular la distancia media por distrito y elegir un punto de corte.

# %%
df.groupby('neighbourhood_group').pdi_sol.median().sort_values()
# Out:
# neighbourhood_group
# Centro                 0.739457
# Arganzuela             1.819518
# Chamberí               2.070150
# Moncloa                2.094636
# Retiro                 2.438337
# Salamanca              2.827565
# Latina                 3.337816
# Carabanchel            3.717970
# Usera                  3.865161
# Puente de Vallecas     4.286299
# Chamartín              4.478116
# Tetuán                 4.638182
# Moratalaz              5.009633
# Ciudad Lineal          5.131551
# Fuencarral             7.528311
# Villaverde             7.579665
# San Blas               8.108111
# Hortaleza              8.119706
# Vicálvaro              8.502931
# Villa de Vallecas      8.754420
# Barajas               11.592324
# Name: pdi_sol, dtype: float64

# %% [markdown]
# Vamos a cortar en Latina incluído.
#
# Y sobre esa selección vamos a visualizar con un scatter.

# %%
df.groupby('neighbourhood_group').pdi_sol.median().sort_values()[0:7].index.to_list()
# Out:
# ['Centro',
#  'Arganzuela',
#  'Chamberí',
#  'Moncloa',
#  'Retiro',
#  'Salamanca',
#  'Latina']

# %%
seleccion = df.groupby('neighbourhood_group').pdi_sol.median().sort_values()[0:7].index.to_list()

plt.figure(figsize = (16,12))
sns.scatterplot(data = df.loc[df.neighbourhood_group.isin(seleccion)], x = 'pdi_sol', y = 'precio_total');

# %% [markdown]
# No parece haber una relación tan directa como sería esperable entre la distancia a la Puerta del Sol y el precio de alquiler.

# %% [markdown]
# **Insight 5: estando dentro del distrito parece que la cercanía a puntos de interés no tiene tanto impacto como sería esperable. Eso abre la puerta a buscar inmuebles que estando en un distrito céntrico no estén justo al lado del PdI y por tanto esperablemente tengan un precio de compra menor**

# %% [markdown]
# ### Analisis sobre la ocupación

# %% [markdown]
# Para este punto podríamos repetir exactamente los mismos análisis que con el precio pero cambiando la variable precio por la de ocupación que habíamos construido.
#
# Dado que sería igual no vamos a desarrollarlo y te lo dejo como tarea para que practiques e intentes obtener tus primeros insights.
#
# En su lugar prefiero el tiempo para enseñarte cómo podemos incluir análisis sobre un mapa, dado que en este caso sería algo muy relevante y es un tipo de análisis que siempre gusta mucho.

# %% [markdown]
# **¿Cual es el ocupación medio? ¿y el rango de ocupación?¿Y por distritos?¿Y por barrios?**
#
# **¿Cual es el ranking de distritos y barrios por ocupación media?**

# %%
df.ocupacion.describe()
# Out:
# count    25873.000000
# mean        54.758204
# std         36.918032
# min          0.000000
# 25%         18.000000
# 50%         56.000000
# 75%         94.000000
# max        100.000000
# Name: ocupacion, dtype: float64

# %% [markdown]
# Vemos que hay al menos un atípico por la parte de arriba que sesga la media, por tanto vamos a usar la mediana como medida de centralización más fiable.

# %%
df.ocupacion.median()
# Out:
# 56.0

# %%
df.groupby('neighbourhood_group').ocupacion.median().sort_values(ascending = False)
# Out:
# neighbourhood_group
# Moratalaz             75.5
# Barajas               75.0
# San Blas              75.0
# Villaverde            73.0
# Retiro                66.0
# Moncloa               65.0
# Latina                63.0
# Fuencarral            62.0
# Arganzuela            61.0
# Hortaleza             57.5
# Centro                57.0
# Salamanca             56.5
# Ciudad Lineal         55.0
# Chamberí              54.5
# Carabanchel           54.5
# Puente de Vallecas    52.0
# Usera                 51.0
# Vicálvaro             50.0
# Chamartín             41.0
# Tetuán                41.0
# Villa de Vallecas     34.0
# Name: ocupacion, dtype: float64

# %% [markdown]
# Nos llama la atención el dato de San Blas, vamos a verlo con más detalle a ver qué está pasando.

# %%
df.loc[df.neighbourhood_group == 'San Blas'].sort_values('ocupacion',ascending = False).head(10)
# Out:
#        index                   id  \
# 6303    6303             35132510
# 6019    6019             34680215
# 6209    6209             34914686
# 6218    6218             34997346
# 6220    6220             34999824
# 6226    6226             34920045
# 6231    6231             34925146
# 6237    6237             35004011
# 6241    6241             35007673
# 21695  21695  1178070221634310360
#
#                                                     name host_response_time  \
# 6303   Se alquila habitacion para la final de la Cham...        no response
# 6019                            Wanda metropolitano Room        no response
# 6209               Alquiler de habitacion a 20 del Wanda        no response
# 6218               Magnífica habitación, CERCA DEL WANDA        no response
# 6220                         Piso final champions league        no response
# 6226           Disfruta la final de la Champions League.        no response
# 6231             EUFA CHAMPIONS LEAGUE FINAL MAY31-JUNE1        no response
# 6237       Bohardilla cerca wanda para final de champios        no response
# 6241       2 bedrooms 4-5 people champions near to wanda        no response
# 21695  靠近市中心，距离马德里机场10分钟车程，地铁口整个房子出租，3个房间3张床，可入住6人，房间有空调     within an hour
#
#       host_is_superhost                host_verifications  \
# 6303                  f                ['email', 'phone']
# 6019                  f                ['email', 'phone']
# 6209                  f                         ['phone']
# 6218                  f                ['email', 'phone']
# 6220                  f                ['email', 'phone']
# 6226                  f                ['email', 'phone']
# 6231                  f  ['email', 'phone', 'work_email']
# 6237                  f                ['email', 'phone']
# 6241                  f                ['email', 'phone']
# 21695                 f                         ['phone']
#
#       host_has_profile_pic host_identity_verified neighbourhood_cleansed  \
# 6303                     t                      f                 Hellín
# 6019                     t                      f                  Rosas
# 6209                     t                      f                Amposta
# 6218                     t                      f               Simancas
# 6220                     t                      f             Canillejas
# 6226                     t                      f               Simancas
# 6231                     t                      f               Simancas
# 6237                     t                      f                  Rosas
# 6241                     t                      t                  Rosas
# 21695                    t                      t                Amposta
#
#                      property_type        room_type  \
# 6303   Private room in rental unit     Private room
# 6019          Private room in home     Private room
# 6209   Private room in rental unit     Private room
# 6218   Private room in rental unit     Private room
# 6220                   Entire home  Entire home/apt
# 6226   Private room in rental unit     Private room
# 6231   Private room in rental unit     Private room
# 6237        Private room in chalet     Private room
# 6241         Private room in condo     Private room
# 21695           Entire rental unit  Entire home/apt
#
#                                                amenities has_availability  \
# 6303                 ["Hot water", "Wifi", "Essentials"]               no
# 6019   ["Breakfast", "Heating", "Wifi", "Hair dryer",...               no
# 6209   ["Free parking on premises", "Hangers", "First...               no
# 6218   ["Hangers", "First aid kit", "Heating", "Wifi"...               no
# 6220   ["Free parking on premises", "Hangers", "Smoki...               no
# 6226   ["Hangers", "Breakfast", "Wifi", "Hair dryer",...               no
# 6231   ["Private living room", "Smoke alarm", "Privat...               no
# 6237   ["Hangers", "Paid parking on premises", "Exter...               no
# 6241   ["Heating", "Wifi", "Hair dryer", "Smoking all...              yes
# 21695  ["Ethernet connection", "Wifi", "Kitchen", "Es...              yes
#
#       license instant_bookable neighbourhood_group    host_id  \
# 6303       no                f            San Blas  123251555
# 6019       no                f            San Blas  261609960
# 6209       no                f            San Blas  263139662
# 6218       no                f            San Blas  263666045
# 6220       no                f            San Blas  160767488
# 6226       no                f            San Blas  263162785
# 6231       no                f            San Blas  133624002
# 6237       no                f            San Blas  191769272
# 6241       no                t            San Blas  250699072
# 21695      no                f            San Blas   88164282
#
#                        host_since  host_response_rate  host_acceptance_rate  \
# 6303   2017-03-29 00:00:00.000000                 0.0                  86.0
# 6019   2019-05-13 00:00:00.000000                 0.0                  75.0
# 6209   2019-05-21 00:00:00.000000                 0.0                  74.0
# 6218   2019-05-23 00:00:00.000000                 0.0                  85.0
# 6220   2017-11-30 00:00:00.000000                 0.0                  80.0
# 6226   2019-05-21 00:00:00.000000                 0.0                  85.0
# 6231   2017-06-05 00:00:00.000000                 0.0                  85.0
# 6237   2018-05-26 00:00:00.000000                 0.0                  75.0
# 6241   2019-03-23 00:00:00.000000                 0.0                  75.0
# 21695  2016-08-05 00:00:00.000000               100.0                  91.0
#
#        host_listings_count  host_total_listings_count   latitude  longitude  \
# 6303                   1.0                        1.0  40.429390  -3.615350
# 6019                   1.0                        1.0  40.427590  -3.603900
# 6209                   1.0                        1.0  40.423830  -3.624980
# 6218                   1.0                        1.0  40.429430  -3.628570
# 6220                   1.0                        1.0  40.440410  -3.610480
# 6226                   2.0                        2.0  40.429660  -3.624700
# 6231                   1.0                        1.0  40.437290  -3.618140
# 6237                   1.0                        2.0  40.427160  -3.600730
# 6241                   1.0                        1.0  40.425750  -3.605480
# 21695                  5.0                        5.0  40.425955  -3.623808
#
#        accommodates  bathrooms  bedrooms  beds  price  minimum_nights  \
# 6303              3        1.0       0.0   2.0     91               1
# 6019              2        1.0       0.0   1.0    173               1
# 6209              2        1.0       2.0   1.0    236               1
# 6218              2        1.0       0.0   1.0    114               1
# 6220              6        1.0       4.0   3.0    123               2
# 6226              3        1.0       0.0   2.0     85               1
# 6231              2        1.0       0.0   1.0    114               1
# 6237              2        1.0       0.0   1.0    173               2
# 6241              4        1.0       2.0   2.0    204               1
# 21695             6        1.0       3.0   3.0    232              30
#
#        maximum_nights  availability_30  availability_60  availability_90  \
# 6303             1125                0                0                0
# 6019                2                0                0                0
# 6209             1125                0                0                0
# 6218             1125                0                0                0
# 6220                2                0                0                0
# 6226                2                0                0                0
# 6231                1                0                0                0
# 6237                2                0                0                0
# 6241             1125                0                0                0
# 21695             365                0                0                0
#
#        availability_365  number_of_reviews  number_of_reviews_ltm  \
# 6303                  0                  0                      0
# 6019                  0                  0                      0
# 6209                  0                  0                      0
# 6218                  0                  0                      0
# 6220                  0                  0                      0
# 6226                  0                  0                      0
# 6231                  0                  0                      0
# 6237                  0                  0                      0
# 6241                  0                  0                      0
# 21695                 0                  8                      8
#
#        number_of_reviews_l30d                first_review  \
# 6303                        0  2017-03-29 00:00:00.000000
# 6019                        0  2019-05-13 00:00:00.000000
# 6209                        0  2019-05-21 00:00:00.000000
# 6218                        0  2019-05-23 00:00:00.000000
# 6220                        0  2017-11-30 00:00:00.000000
# 6226                        0  2019-05-21 00:00:00.000000
# 6231                        0  2017-06-05 00:00:00.000000
# 6237                        0  2018-05-26 00:00:00.000000
# 6241                        0  2019-03-23 00:00:00.000000
# 21695                       0  2024-06-23 00:00:00.000000
#
#                       last_review  review_scores_rating  \
# 6303   2017-03-29 00:00:00.000000                   0.0
# 6019   2019-05-13 00:00:00.000000                   0.0
# 6209   2019-05-21 00:00:00.000000                   0.0
# 6218   2019-05-23 00:00:00.000000                   0.0
# 6220   2017-11-30 00:00:00.000000                   0.0
# 6226   2019-05-21 00:00:00.000000                   0.0
# 6231   2017-06-05 00:00:00.000000                   0.0
# 6237   2018-05-26 00:00:00.000000                   0.0
# 6241   2019-03-23 00:00:00.000000                   0.0
# 21695  2024-08-25 00:00:00.000000                   5.0
#
#        review_scores_accuracy  review_scores_cleanliness  \
# 6303                      0.0                       0.00
# 6019                      0.0                       0.00
# 6209                      0.0                       0.00
# 6218                      0.0                       0.00
# 6220                      0.0                       0.00
# 6226                      0.0                       0.00
# 6231                      0.0                       0.00
# 6237                      0.0                       0.00
# 6241                      0.0                       0.00
# 21695                     5.0                       4.88
#
#        review_scores_checkin  review_scores_communication  \
# 6303                    0.00                         0.00
# 6019                    0.00                         0.00
# 6209                    0.00                         0.00
# 6218                    0.00                         0.00
# 6220                    0.00                         0.00
# 6226                    0.00                         0.00
# 6231                    0.00                         0.00
# 6237                    0.00                         0.00
# 6241                    0.00                         0.00
# 21695                   4.75                         4.88
#
#        review_scores_location  review_scores_value  \
# 6303                     0.00                  0.0
# 6019                     0.00                  0.0
# 6209                     0.00                  0.0
# 6218                     0.00                  0.0
# 6220                     0.00                  0.0
# 6226                     0.00                  0.0
# 6231                     0.00                  0.0
# 6237                     0.00                  0.0
# 6241                     0.00                  0.0
# 21695                    4.63                  5.0
#
#        calculated_host_listings_count  \
# 6303                                1
# 6019                                1
# 6209                                1
# 6218                                1
# 6220                                1
# 6226                                1
# 6231                                1
# 6237                                1
# 6241                                1
# 21695                               5
#
#        calculated_host_listings_count_entire_homes  \
# 6303                                             0
# 6019                                             0
# 6209                                             0
# 6218                                             0
# 6220                                             1
# 6226                                             0
# 6231                                             0
# 6237                                             0
# 6241                                             0
# 21695                                            2
#
#        calculated_host_listings_count_private_rooms  \
# 6303                                              1
# 6019                                              1
# 6209                                              1
# 6218                                              1
# 6220                                              0
# 6226                                              1
# 6231                                              1
# 6237                                              1
# 6241                                              1
# 21695                                             3
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month  \
# 6303                                             0               0.00
# 6019                                             0               0.00
# 6209                                             0               0.00
# 6218                                             0               0.00
# 6220                                             0               0.00
# 6226                                             0               0.00
# 6231                                             0               0.00
# 6237                                             0               0.00
# 6241                                             0               0.00
# 21695                                            0               1.39
#
#        precio_m2  precio_total  ocupacion    bedrooms_disc accommodates_disc  \
# 6303        2996        181.62        100       00_Estudio               0-3
# 6019        2996        173.00        100       00_Estudio               0-3
# 6209        2996        236.00        100           02_Dos               0-3
# 6218        2996        114.00        100       00_Estudio               0-3
# 6220        2996        123.00        100  04_Cuatro o mas              4-16
# 6226        2996        169.62        100       00_Estudio               0-3
# 6231        2996        114.00        100       00_Estudio               0-3
# 6237        2996        173.00        100       00_Estudio               0-3
# 6241        2996        407.62        100           02_Dos                 4
# 21695       2996        232.00        100          03_Tres              4-16
#
#       beds_disc number_of_reviews_disc   m2  precio_compra   pdi_sol  \
# 6303          3                    1-4   40        95872.0  7.582310
# 6019          1                    1-4   40        95872.0  8.506231
# 6209          1                    1-4   70       167776.0  6.682085
# 6218          1                    1-4   40        95872.0  6.486697
# 6220          3                    1-4  120       287616.0  8.291607
# 6226          3                    1-4   40        95872.0  6.812238
# 6231          1                    1-4   40        95872.0  7.567569
# 6237          1                    1-4   40        95872.0  8.765582
# 6241          3                    1-4   70       167776.0  8.346864
# 21695         3                    1-4   90       215712.0  6.812142
#
#        pisos_rentables
# 6303                 1
# 6019                 1
# 6209                 1
# 6218                 1
# 6220                 1
# 6226                 1
# 6231                 1
# 6237                 1
# 6241                 1
# 21695                1

# %% [markdown]
# En el resto no hay sorpresas, con distritos como Salamanca, Centro o Chanmartín a la cabeza.
#
# Pero por ejemplo vemos que la diferencia de precio media entre Retiro y Tetuán es muy baja.
#
# Esto nos lleva a comparar el precio medio por distrito con el precio medio de compra también por distrito.

# %%
temp = df.groupby('neighbourhood_group')[['ocupacion','precio_compra','precio_total']].median()
temp
# Out:
#                      ocupacion  precio_compra  precio_total
# neighbourhood_group
# Arganzuela                61.0       194000.0         85.00
# Barajas                   75.0       147440.0         79.00
# Carabanchel               54.5       108480.0         65.00
# Centro                    57.0       246800.0        111.00
# Chamartín                 41.0       251400.0        109.00
# Chamberí                  54.5       266600.0        104.00
# Ciudad Lineal             55.0       147040.0         78.00
# Fuencarral                62.0       161520.0         82.50
# Hortaleza                 57.5       174720.0         86.00
# Latina                    63.0       110880.0         70.00
# Moncloa                   65.0       195040.0        101.00
# Moratalaz                 75.5       125440.0         47.50
# Puente de Vallecas        52.0        94680.0         65.50
# Retiro                    66.0       221960.0         98.00
# Salamanca                 56.5       313840.0        120.00
# San Blas                  75.0       119840.0         89.81
# Tetuán                    41.0       181440.0         92.00
# Usera                     51.0        99880.0         59.00
# Vicálvaro                 50.0       117880.0         51.00
# Villa de Vallecas         34.0       113200.0         60.00
# Villaverde                73.0        82800.0         60.00

# %%
plt.figure(figsize = (16,8))
sns.scatterplot(data = temp, x = 'precio_compra', y = 'ocupacion')
#Ponemos las etiquetas
for cada in range(0,temp.shape[0]):
    plt.text(temp.precio_compra.iloc[cada], temp.ocupacion.iloc[cada], temp.index[cada])

# %%
plt.figure(figsize = (16,8))
sns.scatterplot(data = temp, x = 'precio_total', y = 'ocupacion')
#Ponemos las etiquetas
for cada in range(0,temp.shape[0]):
    plt.text(temp.precio_total.iloc[cada], temp.ocupacion.iloc[cada], temp.index[cada])

# %% [markdown]
# Hemos analizado esta relación con dos gráficos diferentes que analizados en conjunto tienen mas sentido porque podemos ver como se relaciona precio_compra y precio_total con la ocupación
#
# No hay una relación directa de la ocupación con el precio_total ni precio_compra, por lo que podríamos encontrar buenas rentabilidades en pisos económicos

# %% [markdown]
# A este nivel ya vemos más cosas:
#
# * 1 barrio que sobresale de San Blas
# * Dentro de cada grupo de bajo-medio-alto sí podemos empezar a separarar
#     * Bajo <150K: Amposta
#     * Medio 150K-250K: Arguelles y Cortés
#     * Medio-alto 250K-350K: Almagro
#     * Alto >350K: Castellana
#
# **Insight 6: Existen ciertos barrios que apriori pueden maximizar la relación ingresos-coste debido a que tienen una ocupación alta con precios medios y su precio de compra no se dispara**

# %%
temp = df.groupby('neighbourhood_cleansed')[['ocupacion','precio_total','precio_compra']].median()
temp
# Out:
#                         ocupacion  precio_total  precio_compra
# neighbourhood_cleansed
# Abrantes                     45.0         57.00       108480.0
# Acacias                      64.0         77.62       194000.0
# Adelfas                      74.0         90.00       221960.0
# Aeropuerto                    9.0         56.50       147440.0
# Aguilas                      40.0         50.00       110880.0
# ...                           ...           ...            ...
# Valverde                     40.0         81.00       161520.0
# Ventas                       53.0         64.00       147040.0
# Vinateros                    75.5         32.50       125440.0
# Vista Alegre                 56.0         59.00       108480.0
# Zofío                        26.5         54.50        99880.0
#
# [127 rows x 3 columns]

# %%
plt.figure(figsize = (16,8))
sns.scatterplot(data = temp, x = 'precio_compra', y = 'ocupacion')
#Ponemos las etiquetas
for cada in range(0,temp.shape[0]):
    plt.text(temp.precio_compra.iloc[cada], temp.ocupacion.iloc[cada], temp.index[cada])

# %%
plt.figure(figsize = (16,8))
sns.scatterplot(data = temp, x = 'precio_total', y = 'ocupacion')
#Ponemos las etiquetas
for cada in range(0,temp.shape[0]):
    plt.text(temp.precio_total.iloc[cada], temp.ocupacion.iloc[cada], temp.index[cada])

# %% [markdown]
# **¿Qué factores (a parte de la localización determinan el precio del alquiler?**

# %% [markdown]
# Para responder a esta pregunta podemos construir un minicubo, ya que hemos discretizado nuestras variables de análisis.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25873 entries, 0 to 25872
# Data columns (total 63 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   index                                         25873 non-null  int64
#  1   id                                            25873 non-null  int64
#  2   name                                          25873 non-null  object
#  3   host_response_time                            25873 non-null  object
#  4   host_is_superhost                             25873 non-null  object
#  5   host_verifications                            25873 non-null  object
#  6   host_has_profile_pic                          25873 non-null  object
#  7   host_identity_verified                        25873 non-null  object
#  8   neighbourhood_cleansed                        25873 non-null  object
#  9   property_type                                 25873 non-null  object
#  10  room_type                                     25873 non-null  object
#  11  amenities                                     25873 non-null  object
#  12  has_availability                              25873 non-null  object
#  13  license                                       25873 non-null  object
#  14  instant_bookable                              25873 non-null  object
#  15  neighbourhood_group                           25873 non-null  object
#  16  host_id                                       25873 non-null  int64
#  17  host_since                                    25873 non-null  object
#  18  host_response_rate                            25873 non-null  float64
#  19  host_acceptance_rate                          25873 non-null  float64
#  20  host_listings_count                           25873 non-null  float64
#  21  host_total_listings_count                     25873 non-null  float64
#  22  latitude                                      25873 non-null  float64
#  23  longitude                                     25873 non-null  float64
#  24  accommodates                                  25873 non-null  int64
#  25  bathrooms                                     25873 non-null  float64
#  26  bedrooms                                      25873 non-null  float64
#  27  beds                                          25873 non-null  float64
#  28  price                                         25873 non-null  int64
#  29  minimum_nights                                25873 non-null  int64
#  30  maximum_nights                                25873 non-null  int64
#  31  availability_30                               25873 non-null  int64
#  32  availability_60                               25873 non-null  int64
#  33  availability_90                               25873 non-null  int64
#  34  availability_365                              25873 non-null  int64
#  35  number_of_reviews                             25873 non-null  int64
#  36  number_of_reviews_ltm                         25873 non-null  int64
#  37  number_of_reviews_l30d                        25873 non-null  int64
#  38  first_review                                  25873 non-null  object
#  39  last_review                                   25873 non-null  object
#  40  review_scores_rating                          25873 non-null  float64
#  41  review_scores_accuracy                        25873 non-null  float64
#  42  review_scores_cleanliness                     25873 non-null  float64
#  43  review_scores_checkin                         25873 non-null  float64
#  44  review_scores_communication                   25873 non-null  float64
#  45  review_scores_location                        25873 non-null  float64
#  46  review_scores_value                           25873 non-null  float64
#  47  calculated_host_listings_count                25873 non-null  int64
#  48  calculated_host_listings_count_entire_homes   25873 non-null  int64
#  49  calculated_host_listings_count_private_rooms  25873 non-null  int64
#  50  calculated_host_listings_count_shared_rooms   25873 non-null  int64
#  51  reviews_per_month                             25873 non-null  float64
#  52  precio_m2                                     25873 non-null  int64
#  53  precio_total                                  25873 non-null  float64
#  54  ocupacion                                     25873 non-null  int64
#  55  bedrooms_disc                                 25873 non-null  object
#  56  accommodates_disc                             25873 non-null  object
#  57  beds_disc                                     25873 non-null  object
#  58  number_of_reviews_disc                        25873 non-null  object
#  59  m2                                            25873 non-null  int64
#  60  precio_compra                                 25873 non-null  float64
#  61  pdi_sol                                       25873 non-null  float64
#  62  pisos_rentables                               25873 non-null  int64
# dtypes: float64(20), int64(22), object(21)
# memory usage: 12.4+ MB

# %%
#Paso 1: Seleccionar qué variables serán la métricas y cuales las dimensiones
metricas = ['ocupacion']
dimensiones = ['bedrooms_disc','accommodates_disc','beds_disc','number_of_reviews_disc']

minicubo_ocupacion = df[dimensiones + metricas]
minicubo_ocupacion
# Out:
#       bedrooms_disc accommodates_disc beds_disc number_of_reviews_disc  \
# 0            01_Una               0-3         1                   5-71
# 1            01_Una               0-3         1                71-1136
# 2            01_Una               0-3         1                    1-4
# 3            01_Una               0-3         3                   5-71
# 4            01_Una                 4         3                71-1136
# ...             ...               ...       ...                    ...
# 25868        01_Una               0-3         1                    1-4
# 25869        01_Una                 4         3                    1-4
# 25870        01_Una               0-3         1                    1-4
# 25871        01_Una               0-3         3                    1-4
# 25872        01_Una               0-3         1                    1-4
#
#        ocupacion
# 0             60
# 1            100
# 2            100
# 3            100
# 4              9
# ...          ...
# 25868          0
# 25869          4
# 25870          0
# 25871          4
# 25872         75
#
# [25873 rows x 5 columns]

# %%
#Paso 2: pasar a transaccional las dimensiones
minicubo_ocupacion = minicubo_ocupacion.melt(id_vars=['ocupacion'])
minicubo_ocupacion
# Out:
#         ocupacion                variable   value
# 0              60           bedrooms_disc  01_Una
# 1             100           bedrooms_disc  01_Una
# 2             100           bedrooms_disc  01_Una
# 3             100           bedrooms_disc  01_Una
# 4               9           bedrooms_disc  01_Una
# ...           ...                     ...     ...
# 103487          0  number_of_reviews_disc     1-4
# 103488          4  number_of_reviews_disc     1-4
# 103489          0  number_of_reviews_disc     1-4
# 103490          4  number_of_reviews_disc     1-4
# 103491         75  number_of_reviews_disc     1-4
#
# [103492 rows x 3 columns]

# %%
#Paso 3: Agregar las métricas por "variable" y "valor" con las funciones deseadas
minicubo_ocupacion = minicubo_ocupacion.groupby(['variable','value'])[['ocupacion']].agg('median')
minicubo_ocupacion
# Out:
#                                         ocupacion
# variable               value
# accommodates_disc      0-3                   63.0
#                        4                     51.0
#                        4-16                  50.0
# bedrooms_disc          00_Estudio           100.0
#                        01_Una                50.0
#                        02_Dos                54.0
#                        03_Tres               53.0
#                        04_Cuatro o mas       53.0
# beds_disc              1                     64.0
#                        3                     54.0
#                        3-19                  42.5
# number_of_reviews_disc 1-4                   58.0
#                        5-71                  54.0
#                        71-1136               58.0

# %% [markdown]
# Sobre el minicubo vamos analizando cada variable.

# %%
minicubo_ocupacion.loc['bedrooms_disc']
# Out:
#                  ocupacion
# value
# 00_Estudio           100.0
# 01_Una                50.0
# 02_Dos                54.0
# 03_Tres               53.0
# 04_Cuatro o mas       53.0

# %%
f, ax = plt.subplots()
ax.plot(minicubo_ocupacion.loc['bedrooms_disc'].ocupacion);

# %% [markdown]
# En cuanto al número de habitaciones parece que los estudios son los que mayor ocupación tienen por lo que sería mas rentable

# %%
minicubo_ocupacion.loc['beds_disc']
# Out:
#        ocupacion
# value
# 1           64.0
# 3           54.0
# 3-19        42.5

# %%
f, ax = plt.subplots()
ax.plot(minicubo_ocupacion.loc['beds_disc'].ocupacion);

# %% [markdown]
# En cuanto al número de camas, confirma que hasta 3 camas se ocupa mucho mas
#
# Veámoslo por ejemplo con los pisos de una habitación:

# %%
df[df.bedrooms == 1].groupby('beds').ocupacion.median().plot();

# %% [markdown]
# Vamos a analizar ahora por el número de huéspedes que aceptan

# %%
minicubo_ocupacion.loc['accommodates_disc']
# Out:
#        ocupacion
# value
# 0-3         63.0
# 4           51.0
# 4-16        50.0

# %%
f, ax = plt.subplots()
ax.plot(minicubo_ocupacion.loc['accommodates_disc'].ocupacion);

# %% [markdown]
# **Insight 7: el número óptimo de huéspedes es entre 1 y 3**

# %% [markdown]
# ### Analisis geográfico sobre un mapa
#
# Este mismo análisis por colores se podría hacer por cada una de los zonas o incluso barrios

# %%
#conda install -c conda-forge folium
import folium

#Cargamos el mapa de la zona
mapa = folium.Map(location=[40.4167278, -3.7033387],zoom_start=12)

#Hacemos una selección de los datos disponibles para cargarlos en el mapa
datos = df[df.neighbourhood_group == 'San Blas'].copy()

#Definimos la variable por la que segmentaremos por colores y y los quartiles de segmentación
datos['precio_total_disc'] = pd.qcut(datos['precio_total'], q = [0, .25, .5, .75, 1.], 
                              labels=['yellow', 'orange', 'blue', 'red'])

#Generamos un bucle que recorra la tabla datos y que vaya extrayendo latitud y longitud y añadiéndolos al mapa
for piso in range(0,len(datos)):
   folium.CircleMarker(
      location = [datos.iloc[piso]['latitude'], datos.iloc[piso]['longitude']],
      popup = datos.iloc[piso]['precio_total'],
      fill=True,
      color = datos.iloc[piso]['precio_total_disc'],
      fill_opacity=1,
      radius = 5
   ).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4b32a383799e2e7061ee2e1acf2dc81d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4b32a383799e2e7061ee2e1acf2dc81d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4b32a383799e2e7061ee2e1acf2dc81d = L.map(
#                 &quot;map_4b32a383799e2e7061ee2e1acf2dc81d&quot;,
#                 {
#                     center: [40.4167278, -3.7033387],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_73517e8d5214837629167b735dbf7602 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_73517e8d5214837629167b735dbf7602.addTo(map_4b32a383799e2e7061ee2e1acf2dc81d);
#
#
#             var circle_marker_f22e98501350c603933f8b6c0548c23c = L.circleMarker(
#                 [40.43202, -3.60353],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4b32a383799e2e7061ee2e1acf2dc81d);
#
#
#         var popup_7ad5f91a43c357525161459d038a2387 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0840431e8ef3bec4b26aa170bb8caf51 = $(`&lt;div id=&quot;html_0840431e8ef3bec4b26aa170bb8caf51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;80.0&lt;/div&gt;`)[0];
#                 popup_7ad5f91a43c357525161459d038a2387.setContent(html_0840431e8ef3bec4b26aa170bb8caf51);
#
#
#
#         circle_marker_f22e98501350c603933f8b6c0548c23c.bindPopup(popup_7ad5f91a43c357525161459d038a2387)
#         ;
#
#
#
#
#             var circle_marker_6133f5923c2db2d95dc4ce4877f46893 = L.circleMarker(
#                 [40.4267, -3.61631],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4b32a383799e2e7061ee2e1acf2dc81d);
#
#
#         var popup_b65743832ee71516f7c62840e50da2c2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ab92d4120d9c2ec26fba919989155eb = $(`&lt;div id=&quot;html_1ab92d4120d9c2ec26fba919989155eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;44.0&lt;/div&gt;`)[0];
#                 popup_b65743832ee71516f7c62840e50da2c2.setContent(html_1ab92d4120d9c2ec26fba919989155eb);
#
#
#
#         circle_marker_6133f5923c2db2d95dc4ce4877f46893.bindPopup(popup_b65743832ee71516f7c62840e50da2c2)
#         ;
#
#
#
#
#             var circle_marker_f73cfa725440d91e3895258e1a5da5c2 = L.circleMarker(
#                 [40.43733, -3.6351],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4b32a383799e2e7061ee2e1acf2dc81d);
#
#
#         var popup_e7343325ba4836474e83a36db8107151 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2819f51f88f23f6e9d1ad1a4792bd868 = $(`&lt;div id=&quot;html_2819f51f88f23f6e9d1ad1a4792bd868&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;60.0&lt;/div&gt;`)[0];
#                 popup_e7343325ba4836474e83a36db8107151.setContent(html_2819f51f88f23f6e9d1ad1a4792bd868);
#
#
#
#         circle_marker_f73cfa725440d91e3895258e1a5da5c2.bindPopup(popup_e7343325ba4836474e83a36db8107151)
#         ;
#
#
#
#
#             var circle_marker_d8345483c891e9d15b8e6d963703eafc = L.circleMarker(
#                 [40.440

# %% [markdown]
# **Insight 8: Existen todavía muchos puntos amarillos y naranjas, lo cual puede indicar que todavía existe potencial para explotar más el factor de los eventos deportivos**

# %% [markdown]
# * Insight 1: pueden existir inmuebles con un valor regular residual pero con alto valor en momentos puntuales por acontenicimientos deportivos o espectáculos
# * Insight 2: Existen ciertos barrios que apriori pueden maximizar la relación ingresos-coste y además podemos segmentarlo por el tipo calidad del inmueble en el que nos interes invertir
# * Insight 3: el número de camas a evitar es 2
# * Insight 4: el número óptimo de huéspedes está en 4, ya el precio de los inmuebles no varia demasiado hasta esos ocupantes pero, a partir de 4 el piso necesita ser mayor y el precio de compra se incrementa bastante
# * Insight 5: estando dentro del distrito parece que la cercanía a puntos de interés no tiene tanto impacto como sería esperable. Eso abre la puerta a buscar inmuebles que estando en un distrito céntrico no estén justo al lado del PdI y por tanto esperablemente tengan un precio de compra menor
# * Insight 6: Existen ciertos barrios que apriori pueden maximizar la relación ingresos-coste debido a que tienen una ocupación alta con precios medios y su precio de compra no se dispara
# * Insight 7: el número óptimo de huéspedes es entre 1 y 3
# * Insight 8: Existen todavía muchos puntos amarillos y naranjas, lo cual puede indicar que todavía existe potencial para explotar más el factor de los eventos deportivos
