# %% [markdown]
# # PRESELECCIÓN DE VARIABLES

# %% [markdown]
# ## 1. IMPORTAR PAQUETES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import mutual_info_regression
from sklearn.feature_selection import RFE
from xgboost import XGBClassifier
from xgboost import XGBRegressor
from sklearn.inspection import permutation_importance


#Automcompletar rápido
# %config IPCompleter.greedy=True

# %% [markdown]
# ## 2. IMPORTAR LOS DATOS

# %% [markdown]
# Sustituir la ruta del proyecto.

# %%
ruta_proyecto = 'C:/Users/Oscar/OneDrive - FM4/Escritorio/EVOLVE/Data Science/Proyecto-Master-DataScience-Evolve-OscarFraile'

# %% [markdown]
# Nombres de los ficheros de datos.

# %%
nombre_df = 'df_tablon.pickle'

# %% [markdown]
# Cargar los datos.

# %%
df = pd.read_pickle(ruta_proyecto + '/02_Datos/03_Trabajo/' + nombre_df)

# %% [markdown]
# ## 3. MÉTODOS SUPERVISADOS

# %% [markdown]
# ### 3.1. Preparar x e y

# %%
target = 'pisos_rentables'
x = df.drop(columns = target).copy()
y =  df[target].copy()

# %%
print("Valores únicos de target:", y.unique())
print("Conteo de clases:", y.value_counts())
# Out:
# Valores únicos de target: [1 0]
# Conteo de clases: 1    12554
# 0     5557
# Name: pisos_rentables, dtype: int64

# %% [markdown]
# ### 3.2. Mutual Information

# %% [markdown]
# #### 3.2.1. Crear una función para mostrar el resultado

# %%
def ranking_mi(mutual_selector, modo = 'tabla'):
    #Maqueta el ranking
    ranking_mi = pd.DataFrame(mutual_selector, index = x.columns).reset_index()
    ranking_mi.columns = ['variable','importancia_mi']
    ranking_mi = ranking_mi.sort_values(by = 'importancia_mi', ascending = False)
    ranking_mi['ranking_mi'] = np.arange(0,ranking_mi.shape[0])
    #Muestra la salida
    if modo == 'tabla':
        return(ranking_mi)
    else:
        g = ranking_mi.importancia_mi.sort_values().plot.barh(figsize = (12,20))
        g.set_yticklabels(ranking_mi.sort_values(by = 'importancia_mi').variable)
        return(g)

# %% [markdown]
# #### 3.2.2. Calcular y revisar

# %%
mutual_selector = mutual_info_classif(x,y)

rank_mi = ranking_mi(mutual_selector, modo = 'grafico')

# %%
#Mostrar el máximo de columnas posibles de una tabla
pd.set_option('display.max_rows', 200) #Número de columnas que deben verse. None = Máx
rank_mi = ranking_mi(mutual_selector)
rank_mi.head(126)
# Out:
#                                               variable  importancia_mi  \
# 57                                availability_365_yeo        0.447540
# 85                            availability_365_yeo_mms        0.443251
# 56                                 availability_90_yeo        0.143431
# 84                             availability_90_yeo_mms        0.139593
# 83                             availability_60_yeo_mms        0.115689
# 55                                 availability_60_yeo        0.114453
# 54                                 availability_30_yeo        0.077607
# 82                             availability_30_yeo_mms        0.074706
# 30                               host_response_time_oe        0.034601
# 78                          host_response_rate_yeo_mms        0.034191
# 50                              host_response_rate_yeo        0.032721
# 81                                       price_yeo_mms        0.026825
# 53                                           price_yeo        0.024234
# 58                           host_response_time_oe_mms        0.023587
# 70          calculated_host_listings_count_disc_ds_mms        0.023403
# 80                              maximum_nights_yeo_mms        0.022599
# 52                                  maximum_nights_yeo        0.021202
# 41                              maximum_nights_disc_ds        0.020839
# 42              calculated_host_listings_count_disc_ds        0.020289
# 69                          maximum_nights_disc_ds_mms        0.018786
# 43   calculated_host_listings_count_entire_homes_di...        0.018121
# 71   calculated_host_listings_count_entire_homes_di...        0.015056
# 63                             has_availability_oe_mms        0.014318
# 35                                 has_availability_oe        0.013005
# 118                                              maker        0.011623
# 37                                 instant_bookable_oe        0.009640
# 25                          neighbourhood_group_Tetuán        0.009180
# 72   calculated_host_listings_count_private_rooms_d...        0.008101
# 100                                       conditioning        0.008006
# 45   calculated_host_listings_count_shared_rooms_di...        0.007323
# 111                                            freezer        0.007301
# 134                                       wifi kitchen        0.006750
# 32                               host_verifications_oe        0.006668
# 120                                  microwave hangers        0.006656
# 109                                   dryer bed linens        0.006251
# 6                            room_type_Entire home/apt        0.005992
# 103                                          dedicated        0.005839
# 22                          neighbourhood_group_Retiro        0.005815
# 61                         host_has_profile_pic_oe_mms        0.005305
# 98                                              coffee        0.005198
# 17                       neighbourhood_group_Hortaleza        0.005098
# 86                                                 air        0.004885
# 62                       host_identity_verified_oe_mms        0.004802
# 121                                               oven        0.004784
# 21              neighbourhood_group_Puente de Vallecas        0.004658
# 124                                               room        0.004465
# 34                           host_identity_verified_oe        0.004428
# 125                                            shampoo        0.004227
# 107                              dishes and silverware        0.004174
# 117                                             linens        0.004024
# 48                                    bedrooms_disc_ds        0.003916
# 65                             instant_bookable_oe_mms        0.003655
# 135                                          workspace        0.003570
# 88                                             allowed        0.003388
# 99                                        coffee maker        0.003298
# 129                                            storage        0.003199
# 44   calculated_host_listings_count_private_rooms_d...        0.003025
# 23                       neighbourhood_group_Salamanca        0.003007
# 77                       number_of_reviews_disc_ds_mms        0.002884
# 5            property_type_Private room in rental unit        0.002869
# 33                             host_has_profile_pic_oe        0.002842
# 31                                host_is_superhost_oe        0.002752
# 73   calculated_host_listings_count_shared_rooms_di...        0.002649
# 96                                            clothing        0.002630
# 12                          neighbourhood_group_Centro        0.002561
# 110                                           elevator        0.002557
# 28               neighbourhood_group_Villa de Vallecas        0.002538
# 13                       neighbourhood_group_Chamartín        0.002485
# 20                       neighbourhood_group_Moratalaz        0.002440
# 11                     neighbourhood_group_Carabanchel        0.002430
# 114                                                 in        0.002347
# 90                                              basics        0.002068
# 4                   property_type_Private room in home        0.002051
# 128                                      stays allowed        0.002031
# 16                      neighbourhood_group_Fuencarral        0.001937
# 97                                    clothing storage        0.001814
# 91                                                 bed        0.001796
# 49                           number_of_reviews_disc_ds        0.001778
# 51                                    accommodates_yeo        0.001772
# 27                       neighbourhood_group_Vicálvaro        0.001691
# 108                                          dryer bed        0.001602
# 127                                               soap        0.001544
# 18                          neighbourhood_group_Latina        0.001536
# 119                                          microwave        0.001491
# 113                                     hot water iron        0.001144
# 75                                    beds_disc_ds_mms        0.001125
# 106                                         dishes and        0.001051
# 24                        neighbourhood_group_San Blas        0.001041
# 95                                            cleaning        0.000952
# 1                            property_type_Entire loft        0.000915
# 7                               room_type_Private room        0.000909
# 101                                            cooking        0.000906
# 122                                            parking        0.000854
# 60                           host_verifications_oe_mms        0.000762
# 94                                           body soap        0.000746
# 131                                            toaster        0.000599
# 116                                 kitchen essentials        0.000496
# 79                                accommodates_yeo_mms        0.000494
# 105                                             dishes        0.000399
# 15                   neighbourhood_group_Ciudad Lineal        0.000311
# 126                                         silverware        0.000306
# 74                            accommodates_disc_ds_mms        0.000123
# 40                              minimum_nights_disc_ds        0.000076
# 59                            host_is_superhost_oe_mms        0.000057
# 115                                               iron        0.000000
# 132                                          tv washer        0.000000
# 130                                              stove        0.000000
# 112                                     hair dryer bed        0.000000
# 123                                       refrigerator        0.000000
# 133                                         water iron        0.000000
# 0                           property_type_Entire condo        0.000000
# 104                                dedicated workspace        0.000000
# 38                                   bathrooms_disc_ds        0.000000
# 2                     property_type_Entire rental unit        0.000000
# 3                                  property_type_OTROS        0.000000
# 8                                room_type_Shared room        0.000000
# 9                       neighbourhood_group_Arganzuela        0.000000
# 10                         neighbourhood_group_Barajas        0.000000
# 14                        neighbourhood_group_Chamberí        0.000000
# 19                         neighbourhood_group_Moncloa        0.000000
# 26                           neighbourhood_group_Usera        0.000000
# 29                      neighbourhood_group_Villaverde        0.000000
# 36                                          license_oe        0.000000
# 39                                       price_disc_ds        0.000000
# 102                                     cooking basics        0.000000
# 46                                accommodates_disc_ds        0.000000
#
#      ranking_mi
# 57            0
# 85            1
# 56            2
# 84            3
# 83            4
# 55            5
# 54            6
# 82            7
# 30            8
# 78            9
# 50           10
# 81           11
# 53           12
# 58           13
# 70           14
# 80           15
# 52           16
# 41           17
# 42           18
# 69           19
# 43           20
# 71           21
# 63           22
# 35           23
# 118          24
# 37           25
# 25           26
# 72           27
# 100          28
# 45           29
# 111          30
# 134          31
# 32           32
# 120          33
# 109          34
# 6            35
# 103          36
# 22           37
# 61           38
# 98           39
# 17           40
# 86           41
# 62           42
# 121          43
# 21           44
# 124          45
# 34           46
# 125          47
# 107          48
# 117          49
# 48           50
# 65           51
# 135          52
# 88           53
# 99           54
# 129          55
# 44           56
# 23           57
# 77           58
# 5            59
# 33           60
# 31           61
# 73           62
# 96           63
# 12           64
# 110          65
# 28           66
# 13           67
# 20           68
# 11           69
# 114          70
# 90           71
# 4            72
# 128          73
# 16           74
# 97           75
# 91           76
# 49           77
# 51           78
# 27           79
# 108          80
# 127          81
# 18           82
# 119          83
# 113          84
# 75           85
# 106          86
# 24           87
# 95           88
# 1            89
# 7            90
# 101          91
# 122          92
# 60           93
# 94           94
# 131          95
# 116          96
# 79           97
# 105          98
# 15           99
# 126         100
# 74          101
# 40          102
# 59          103
# 115         104
# 132         105
# 130         106
# 112         107
# 123         108
# 133         109
# 0           110
# 104         111
# 38          112
# 2           113
# 3           114
# 8           115
# 9           116
# 10          117
# 14          118
# 19          119
# 26          120
# 29          121
# 36          122
# 39          123
# 102         124
# 46          125

# %% [markdown]
# #### 3.2.3. Seleccionar las variables que pasan

# %% [markdown]
# ##### Definir la posición de la última variable que va a entrar

# %%
posicion_variable_limite = 99

# %% [markdown]
# ##### Extraer los nombres de las que entran

# %%
entran_mi = ranking_mi(mutual_selector).iloc[0:posicion_variable_limite].variable

# %% [markdown]
# ##### Crear el dataframe con la selección

# %%
x_mi = x[entran_mi].copy()

# %% [markdown]
# ### 3.3. Recursive Feature Elimination

# %% [markdown]
# #### 3.3.1. Instanciar

# %%
rfe = RFE(estimator = XGBClassifier( n_jobs = -1, eval_metric='auc'))

# %% [markdown]
# #### 3.3.2. Entrenar

# %%
rfe.fit(x,y)
# Out:
# RFE(estimator=XGBClassifier(base_score=None, booster=None, callbacks=None,
#                             colsample_bylevel=None, colsample_bynode=None,
#                             colsample_bytree=None, device=None,
#                             early_stopping_rounds=None,
#                             enable_categorical=False, eval_metric='auc',
#                             feature_types=None, gamma=None, grow_policy=None,
#                             importance_type=None, interaction_constraints=None,
#                             learning_rate=None, max_bin=None,
#                             max_cat_threshold=None, max_cat_to_onehot=None,
#                             max_delta_step=None, max_depth=None,
#                             max_leaves=None, min_child_weight=None, missing=nan,
#                             monotone_constraints=None, multi_strategy=None,
#                             n_estimators=None, n_jobs=-1,
#                             num_parallel_tree=None, random_state=None, ...))

# %% [markdown]
# ##### Extraer los nombres de las que entran

# %%
entran_rfe = x.columns[rfe.support_]

# %% [markdown]
# #### 3.3.3. Crear el dataframe con la selección

# %%
x_rfe = x[entran_rfe].copy()

# %% [markdown]
# ### 3.4. Permutation Importance

# %% [markdown]
# #### 3.4.1. Crear una función para mostrar el resultado

# %%
def ranking_per(predictoras,permutxacion):
    ranking_per = pd.DataFrame({'variable': predictoras.columns, 'importancia_per': permutacion.importances_mean}).sort_values(by = 'importancia_per', ascending = False)
    ranking_per['ranking_per'] = np.arange(0,ranking_per.shape[0])
    return(ranking_per)

# %% [markdown]
# #### 3.4.2. Instanciar y entrenar

# %%
import warnings
warnings.filterwarnings(action="ignore", message=r'.*Use subset.*of np.ndarray is not recommended')
xgb = XGBClassifier(n_jobs = -1, eval_metric='auc')
xgb.fit(x,y)
permutacion = permutation_importance(xgb, 
                                     x, y, 
                                     scoring = 'roc_auc',
                                     n_repeats=5, n_jobs = -1)

# %% [markdown]
# #### 3.4.3. Revisar la salida

# %%
rank_per = ranking_per(x,permutacion)

rank_per.set_index('variable').importancia_per.sort_values().plot.barh(figsize = (12,19));

# %% [markdown]
# #### 3.4.4. Seleccionar las variables que pasan

# %%
#Formato sin notación científica
pd.options.display.float_format = '{:15.2f}'.format 
rank_per = ranking_per(x,permutacion)
rank_per.head(126)
# Out:
#                                               variable  importancia_per  \
# 57                                availability_365_yeo             0.45
# 53                                           price_yeo             0.04
# 48                                    bedrooms_disc_ds             0.00
# 23                       neighbourhood_group_Salamanca             0.00
# 12                          neighbourhood_group_Centro             0.00
# 14                        neighbourhood_group_Chamberí             0.00
# 21              neighbourhood_group_Puente de Vallecas             0.00
# 26                           neighbourhood_group_Usera             0.00
# 11                     neighbourhood_group_Carabanchel             0.00
# 51                                    accommodates_yeo             0.00
# 13                       neighbourhood_group_Chamartín             0.00
# 47                                        beds_disc_ds             0.00
# 29                      neighbourhood_group_Villaverde             0.00
# 6                            room_type_Entire home/apt             0.00
# 18                          neighbourhood_group_Latina             0.00
# 22                          neighbourhood_group_Retiro             0.00
# 56                                 availability_90_yeo             0.00
# 46                                accommodates_disc_ds             0.00
# 55                                 availability_60_yeo             0.00
# 24                        neighbourhood_group_San Blas             0.00
# 54                                 availability_30_yeo             0.00
# 52                                  maximum_nights_yeo             0.00
# 9                       neighbourhood_group_Arganzuela             0.00
# 50                              host_response_rate_yeo             0.00
# 132                                          tv washer             0.00
# 37                                 instant_bookable_oe             0.00
# 2                     property_type_Entire rental unit             0.00
# 86                                                 air             0.00
# 131                                            toaster             0.00
# 110                                           elevator             0.00
# 20                       neighbourhood_group_Moratalaz             0.00
# 113                                     hot water iron             0.00
# 125                                            shampoo             0.00
# 90                                              basics             0.00
# 130                                              stove             0.00
# 15                   neighbourhood_group_Ciudad Lineal             0.00
# 31                                host_is_superhost_oe             0.00
# 30                               host_response_time_oe             0.00
# 95                                            cleaning             0.00
# 111                                            freezer             0.00
# 114                                                 in             0.00
# 134                                       wifi kitchen             0.00
# 5            property_type_Private room in rental unit             0.00
# 17                       neighbourhood_group_Hortaleza             0.00
# 96                                            clothing             0.00
# 116                                 kitchen essentials             0.00
# 88                                             allowed             0.00
# 123                                       refrigerator             0.00
# 27                       neighbourhood_group_Vicálvaro             0.00
# 42              calculated_host_listings_count_disc_ds             0.00
# 122                                            parking             0.00
# 89                                      and silverware             0.00
# 115                                               iron             0.00
# 120                                  microwave hangers             0.00
# 91                                                 bed             0.00
# 43   calculated_host_listings_count_entire_homes_di...             0.00
# 108                                          dryer bed             0.00
# 118                                              maker             0.00
# 119                                          microwave             0.00
# 3                                  property_type_OTROS             0.00
# 103                                          dedicated             0.00
# 33                             host_has_profile_pic_oe             0.00
# 32                               host_verifications_oe             0.00
# 10                         neighbourhood_group_Barajas             0.00
# 19                         neighbourhood_group_Moncloa             0.00
# 97                                    clothing storage             0.00
# 121                                               oven             0.00
# 49                           number_of_reviews_disc_ds             0.00
# 124                                               room             0.00
# 28               neighbourhood_group_Villa de Vallecas             0.00
# 128                                      stays allowed             0.00
# 16                      neighbourhood_group_Fuencarral             0.00
# 8                                room_type_Shared room             0.00
# 41                              maximum_nights_disc_ds             0.00
# 93                                                body             0.00
# 99                                        coffee maker             0.00
# 25                          neighbourhood_group_Tetuán             0.00
# 7                               room_type_Private room             0.00
# 44   calculated_host_listings_count_private_rooms_d...             0.00
# 36                                          license_oe             0.00
# 98                                              coffee             0.00
# 34                           host_identity_verified_oe             0.00
# 4                   property_type_Private room in home             0.00
# 39                                       price_disc_ds             0.00
# 45   calculated_host_listings_count_shared_rooms_di...             0.00
# 101                                            cooking             0.00
# 102                                     cooking basics             0.00
# 133                                         water iron             0.00
# 117                                             linens             0.00
# 112                                     hair dryer bed             0.00
# 100                                       conditioning             0.00
# 104                                dedicated workspace             0.00
# 105                                             dishes             0.00
# 106                                         dishes and             0.00
# 107                              dishes and silverware             0.00
# 129                                            storage             0.00
# 109                                   dryer bed linens             0.00
# 127                                               soap             0.00
# 126                                         silverware             0.00
# 0                           property_type_Entire condo             0.00
# 68                          minimum_nights_disc_ds_mms             0.00
# 94                                           body soap             0.00
# 63                             has_availability_oe_mms             0.00
# 69                          maximum_nights_disc_ds_mms             0.00
# 1                            property_type_Entire loft             0.00
# 67                                   price_disc_ds_mms             0.00
# 66                               bathrooms_disc_ds_mms             0.00
# 65                             instant_bookable_oe_mms             0.00
# 64                                      license_oe_mms             0.00
# 62                       host_identity_verified_oe_mms             0.00
# 92                                          bed linens             0.00
# 61                         host_has_profile_pic_oe_mms             0.00
# 60                           host_verifications_oe_mms             0.00
# 59                            host_is_superhost_oe_mms             0.00
# 58                           host_response_time_oe_mms             0.00
# 40                              minimum_nights_disc_ds             0.00
# 35                                 has_availability_oe             0.00
# 70          calculated_host_listings_count_disc_ds_mms             0.00
# 71   calculated_host_listings_count_entire_homes_di...             0.00
# 72   calculated_host_listings_count_private_rooms_d...             0.00
# 73   calculated_host_listings_count_shared_rooms_di...             0.00
# 87                                    air conditioning             0.00
# 85                            availability_365_yeo_mms             0.00
# 84                             availability_90_yeo_mms             0.00
# 83                             availability_60_yeo_mms             0.00
# 82                             availability_30_yeo_mms             0.00
#
#      ranking_per
# 57             0
# 53             1
# 48             2
# 23             3
# 12             4
# 14             5
# 21             6
# 26             7
# 11             8
# 51             9
# 13            10
# 47            11
# 29            12
# 6             13
# 18            14
# 22            15
# 56            16
# 46            17
# 55            18
# 24            19
# 54            20
# 52            21
# 9             22
# 50            23
# 132           24
# 37            25
# 2             26
# 86            27
# 131           28
# 110           29
# 20            30
# 113           31
# 125           32
# 90            33
# 130           34
# 15            35
# 31            36
# 30            37
# 95            38
# 111           39
# 114           40
# 134           41
# 5             42
# 17            43
# 96            44
# 116           45
# 88            46
# 123           47
# 27            48
# 42            49
# 122           50
# 89            51
# 115           52
# 120           53
# 91            54
# 43            55
# 108           56
# 118           57
# 119           58
# 3             59
# 103           60
# 33            61
# 32            62
# 10            63
# 19            64
# 97            65
# 121           66
# 49            67
# 124           68
# 28            69
# 128           70
# 16            71
# 8             72
# 41            73
# 93            74
# 99            75
# 25            76
# 7             77
# 44            78
# 36            79
# 98            80
# 34            81
# 4             82
# 39            83
# 45            84
# 101           85
# 102           86
# 133           87
# 117           88
# 112           89
# 100           90
# 104           91
# 105           92
# 106           93
# 107           94
# 129           95
# 109           96
# 127           97
# 126           98
# 0             99
# 68           100
# 94           101
# 63           102
# 69           103
# 1            104
# 67           105
# 66           106
# 65           107
# 64           108
# 62           109
# 92           110
# 61           111
# 60           112
# 59           113
# 58           114
# 40           115
# 35           116
# 70           117
# 71           118
# 72           119
# 73           120
# 87           121
# 85           122
# 84           123
# 83           124
# 82           125

# %% [markdown]
# ##### Definir la posición de la última variable que va a entrar

# %%
posicion_variable_limite = 1

# %% [markdown]
# ##### Extraer los nombres de las que entran

# %%
entran_per = rank_per.iloc[0:posicion_variable_limite].variable

# %% [markdown]
# ##### Crear el dataframe con la selección

# %%
x_per = x[entran_per].copy()

# %% [markdown]
# ### 3.5. SUPER RANKING

# %% [markdown]
# Otra forma es hacer los métodos y despues un SUPER RANKING para hacer la selección

# %%
#PASO 1. Preparar x e y. Cuidado si no se ha definido la target previamente
target = 'pisos_rentables'
x = df.drop(columns = target).copy()
y = df[target].copy()

#PASO 2. MÉTODOS PRESELECCION
#Método 1. MUTUAL INFORMATION
def ranking_mi(mutual_selector, modo = 'tabla'):
    #Maqueta el ranking
    ranking_mi = pd.DataFrame(mutual_selector, index = x.columns).reset_index()
    ranking_mi.columns = ['variable','importancia_mi']
    ranking_mi = ranking_mi.sort_values(by = 'importancia_mi', ascending = False)
    ranking_mi['ranking_mi'] = np.arange(0,ranking_mi.shape[0])
    #Muestra la salida
    if modo == 'tabla':
        return(ranking_mi)
    else:
        g = ranking_mi.importancia_mi.sort_values().plot.barh(figsize = (12,20))
        g.set_yticklabels(ranking_mi.sort_values(by = 'importancia_mi').variable)
        return(g)
mutual_selector = mutual_info_classif(x,y)
x_mi = ranking_mi(mutual_selector)
x_mi

#Método 2. RECURSIVE FEATURE ELIMINATION SIN validación cruzada
rfe = RFE(estimator = XGBClassifier(n_jobs = -1, eval_metric='auc'))
rfe.fit(x,y)
#Ranking. Las 1 son las que él seleccionaría para maximizar la métrica.
rfe.ranking_
#Dataframe de variable y ranking
x_rfe = pd.DataFrame({'variable': x.columns, 'ranking_rfe': rfe.ranking_}).sort_values(by = 'ranking_rfe')

#Método 3. PERMUTATION IMPORTANCE
xgb = XGBClassifier(use_label_encoder=False, n_jobs = -1, eval_metric='auc')
xgb.fit(x,y)
permutacion = permutation_importance(xgb, 
                                     x, y, 
                                     scoring = 'roc_auc',#Metrica regresión o clasificación
                                     n_repeats=5, n_jobs = -1)
#Creamos una función que nos genere un dataframe con la importancia y una columna de ranking.
def ranking_per(predictoras,permutacion):
    ranking_per = pd.DataFrame({'variable': predictoras.columns, 'importancia_per': permutacion.importances_mean}).sort_values(by = 'importancia_per', ascending = False)
    ranking_per['ranking_per'] = np.arange(0,ranking_per.shape[0])
    return(ranking_per)
x_per = ranking_per(x,permutacion)
x_per

#PASO 3. SUPER RANKING
#Función para unir todas los métodos anteriores en un solo dataframe
def ranking_tot(x_mi, x_rfe, x_per):
    ranking_tot = pd.merge(pd.merge(x_mi, x_rfe), x_per)
    ranking_tot['puntos'] = ranking_tot.ranking_mi + ranking_tot.ranking_rfe + ranking_tot.ranking_per
    ranking_tot.sort_values(by = 'puntos', inplace=True)
    ranking_tot['ranking_tot'] = range(0,len(ranking_tot.variable))
    return(ranking_tot)
super_ranking = ranking_tot(x_mi, x_rfe, x_per)
super_ranking
#Seleccionamos el número de las variables con las que queremos trabajar. Ej. [0:20]
x_sr = x[ranking_tot(x_mi, x_rfe, x_per)[0:57].variable].copy()
x_sr

#Gráfico 20 primeras variables según los puntos
#super_ranking.set_index('variable').puntos.sort_values(ascending = False).plot.barh(figsize = (8,10));
#Gráfico 20 primeras variables según el ranking_tot
#super_ranking.set_index('variable').ranking_tot[0:20].sort_values(ascending = False).plot.barh(figsize = (8,10));

#Despues de este proceso haríamos la modelización de ML para predecir resultados
# Out:
#        availability_365_yeo       price_yeo  availability_90_yeo  \
# 0                     -1.56           -0.03                -1.44
# 1                     -1.56            0.44                -1.44
# 2                      1.04           -0.50                 0.67
# 3                     -1.56            0.07                -1.44
# 4                      0.83           -0.26                -0.51
# ...                     ...             ...                  ...
# 18106                  1.15            1.54                 1.16
# 18107                  1.15           -0.16                 1.16
# 18108                  1.15           -2.69                 1.15
# 18109                  1.09            1.54                 0.91
# 18110                 -0.11            0.84                 1.16
#
#        availability_60_yeo  availability_30_yeo  maximum_nights_yeo  \
# 0                    -1.38                -1.27                0.65
# 1                    -1.38                -1.27               -0.64
# 2                     0.73                 0.65               -1.48
# 3                    -1.38                -1.27               -0.08
# 4                    -0.16                 0.65               -0.10
# ...                    ...                  ...                 ...
# 18106                 1.27                 1.46               -0.08
# 18107                 1.27                 1.46               -1.66
# 18108                 1.25                 1.42               -1.64
# 18109                 0.88                 0.65               -0.08
# 18110                 1.27                 1.46               -0.26
#
#        host_response_rate_yeo  host_response_time_oe  \
# 0                       -1.84                   0.00
# 1                       -1.84                   0.00
# 2                        0.62                   4.00
# 3                       -1.84                   0.00
# 4                        0.62                   4.00
# ...                       ...                    ...
# 18106                    0.62                   3.00
# 18107                    0.62                   4.00
# 18108                   -1.84                   0.00
# 18109                    0.62                   3.00
# 18110                    0.62                   4.00
#
#        neighbourhood_group_Centro  property_type_Entire rental unit  ...  \
# 0                            1.00                              0.00  ...
# 1                            1.00                              1.00  ...
# 2                            1.00                              0.00  ...
# 3                            1.00                              1.00  ...
# 4                            1.00                              1.00  ...
# ...                           ...                               ...  ...
# 18106                        0.00                              1.00  ...
# 18107                        0.00                              0.00  ...
# 18108                        1.00                              0.00  ...
# 18109                        0.00                              1.00  ...
# 18110                        0.00                              1.00  ...
#
#        parking  neighbourhood_group_Latina  room  \
# 0            0                        0.00     0
# 1            0                        0.00     0
# 2            0                        0.00     1
# 3            1                        0.00     0
# 4            1                        0.00     0
# ...        ...                         ...   ...
# 18106        0                        0.00     1
# 18107        0                        0.00     0
# 18108        0                        0.00     0
# 18109        0                        1.00     1
# 18110        1                        0.00     0
#
#        property_type_Private room in rental unit  basics  \
# 0                                           0.00       0
# 1                                           0.00       0
# 2                                           1.00       1
# 3                                           0.00       1
# 4                                           0.00       1
# ...                                          ...     ...
# 18106                                       0.00       1
# 18107                                       1.00       0
# 18108                                       1.00       0
# 18109                                       0.00       1
# 18110                                       0.00       0
#
#        neighbourhood_group_Usera  freezer  refrigerator  \
# 0                           0.00        0             0
# 1                           0.00        0             0
# 2                           0.00        0             1
# 3                           0.00        0             1
# 4                           0.00        1             1
# ...                          ...      ...           ...
# 18106                       0.00        0             1
# 18107                       0.00        0             0
# 18108                       0.00        0             0
# 18109                       0.00        0             1
# 18110                       0.00        0             0
#
#        neighbourhood_group_Hortaleza  tv washer
# 0                               0.00          0
# 1                               0.00          1
# 2                               0.00          0
# 3                               0.00          1
# 4                               0.00          0
# ...                              ...        ...
# 18106                           0.00          1
# 18107                           0.00          0
# 18108                           0.00          0
# 18109                           0.00          1
# 18110                           0.00          1
#
# [18111 rows x 57 columns]

# %%
super_ranking.set_index('variable').puntos[0:50].sort_values(ascending = False).plot.barh(figsize = (8,10));

# %% [markdown]
# ## 4. SELECCIONAR EL MÉTODO FINAL

# %% [markdown]
# Descomentar el método de preselección elegido y dejar comentados el resto.

# %%
# x_preseleccionado = x_mi
# x_preseleccionado = x_rfe
# x_preseleccionado = x_per
x_preseleccionado = x_sr

# %%
x_sr
# Out:
#        availability_365_yeo       price_yeo  availability_90_yeo  \
# 0                     -1.56           -0.03                -1.44
# 1                     -1.56            0.44                -1.44
# 2                      1.04           -0.50                 0.67
# 3                     -1.56            0.07                -1.44
# 4                      0.83           -0.26                -0.51
# ...                     ...             ...                  ...
# 18106                  1.15            1.54                 1.16
# 18107                  1.15           -0.16                 1.16
# 18108                  1.15           -2.69                 1.15
# 18109                  1.09            1.54                 0.91
# 18110                 -0.11            0.84                 1.16
#
#        availability_60_yeo  availability_30_yeo  maximum_nights_yeo  \
# 0                    -1.38                -1.27                0.65
# 1                    -1.38                -1.27               -0.64
# 2                     0.73                 0.65               -1.48
# 3                    -1.38                -1.27               -0.08
# 4                    -0.16                 0.65               -0.10
# ...                    ...                  ...                 ...
# 18106                 1.27                 1.46               -0.08
# 18107                 1.27                 1.46               -1.66
# 18108                 1.25                 1.42               -1.64
# 18109                 0.88                 0.65               -0.08
# 18110                 1.27                 1.46               -0.26
#
#        host_response_rate_yeo  host_response_time_oe  \
# 0                       -1.84                   0.00
# 1                       -1.84                   0.00
# 2                        0.62                   4.00
# 3                       -1.84                   0.00
# 4                        0.62                   4.00
# ...                       ...                    ...
# 18106                    0.62                   3.00
# 18107                    0.62                   4.00
# 18108                   -1.84                   0.00
# 18109                    0.62                   3.00
# 18110                    0.62                   4.00
#
#        neighbourhood_group_Centro  property_type_Entire rental unit  ...  \
# 0                            1.00                              0.00  ...
# 1                            1.00                              1.00  ...
# 2                            1.00                              0.00  ...
# 3                            1.00                              1.00  ...
# 4                            1.00                              1.00  ...
# ...                           ...                               ...  ...
# 18106                        0.00                              1.00  ...
# 18107                        0.00                              0.00  ...
# 18108                        1.00                              0.00  ...
# 18109                        0.00                              1.00  ...
# 18110                        0.00                              1.00  ...
#
#        parking  neighbourhood_group_Latina  room  \
# 0            0                        0.00     0
# 1            0                        0.00     0
# 2            0                        0.00     1
# 3            1                        0.00     0
# 4            1                        0.00     0
# ...        ...                         ...   ...
# 18106        0                        0.00     1
# 18107        0                        0.00     0
# 18108        0                        0.00     0
# 18109        0                        1.00     1
# 18110        1                        0.00     0
#
#        property_type_Private room in rental unit  basics  \
# 0                                           0.00       0
# 1                                           0.00       0
# 2                                           1.00       1
# 3                                           0.00       1
# 4                                           0.00       1
# ...                                          ...     ...
# 18106                                       0.00       1
# 18107                                       1.00       0
# 18108                                       1.00       0
# 18109                                       0.00       1
# 18110                                       0.00       0
#
#        neighbourhood_group_Usera  freezer  refrigerator  \
# 0                           0.00        0             0
# 1                           0.00        0             0
# 2                           0.00        0             1
# 3                           0.00        0             1
# 4                           0.00        1             1
# ...                          ...      ...           ...
# 18106                       0.00        0             1
# 18107                       0.00        0             0
# 18108                       0.00        0             0
# 18109                       0.00        0             1
# 18110                       0.00        0             0
#
#        neighbourhood_group_Hortaleza  tv washer
# 0                               0.00          0
# 1                               0.00          1
# 2                               0.00          0
# 3                               0.00          1
# 4                               0.00          0
# ...                              ...        ...
# 18106                           0.00          1
# 18107                           0.00          0
# 18108                           0.00          0
# 18109                           0.00          1
# 18110                           0.00          1
#
# [18111 rows x 57 columns]

# %% [markdown]
# ## 5. MÉTODOS NO SUPERVISADOS

# %% [markdown]
# ### 5.1. Correlación

# %% [markdown]
# #### 5.1.1. Crear una función para mostrar el resultado

# %%
def correlaciones_fuertes(df, lim_inf = 0.3, lim_sup = 1,drop_dupli=True):
    #Calcula la matriz de correlación
    c = df.corr().abs()
    #Lo pasa todo a filas
    c= c.unstack()
    #Pasa el índice a columnas y le pone nombres
    c = pd.DataFrame(c).reset_index()
    c.columns = ['var1','var2','corr']
    #A dataframe, filtra limites y ordena en descendiente
    c = c.loc[(c['corr'] > lim_inf) &  (c['corr'] < lim_sup),:].sort_values(by = 'corr', ascending=False)
    #Desduplica las correlaciones (o no si drop_dupli es False)
    c = c if drop_dupli == False else c.drop_duplicates(subset = ['corr'])
    #Devuelve la salida
    return(c)

# %% [markdown]
# #### 5.1.2. Calcular y revisar

# %% [markdown]
# ##### Calcular

# %%
cor_finales = correlaciones_fuertes(x_preseleccionado)

# %% [markdown]
# ##### Revisar agregado

# %%
#Número de veces que var1 aparece en relacion con diferentes variables. Ej. var1//variacion_tasa_empleo_bin_rs = 6 veces
cor_finales.var1.value_counts()
# Out:
# dryer bed                                    9
# kitchen essentials                           8
# host_response_rate_yeo                       8
# maker                                        8
# freezer                                      7
# room                                         7
# stays allowed                                7
# refrigerator                                 6
# room_type_Private room                       6
# property_type_Entire rental unit             5
# accommodates_yeo                             5
# host_response_time_oe                        5
# stove                                        5
# room_type_Entire home/apt                    5
# basics                                       5
# clothing                                     4
# price_yeo                                    4
# availability_60_yeo                          4
# bedrooms_disc_ds                             3
# availability_365_yeo                         3
# beds_disc_ds                                 3
# availability_30_yeo                          2
# air                                          2
# parking                                      2
# maximum_nights_disc_ds                       1
# calculated_host_listings_count_disc_ds       1
# availability_90_yeo                          1
# tv washer                                    1
# accommodates_disc_ds                         1
# property_type_Private room in rental unit    1
# shampoo                                      1
# Name: var1, dtype: int64

# %% [markdown]
# ##### Revisar detalle

# %%
#Opciones si hay muchas variables con altas correlaciones:
#1. Rehacer el reescalado porque se ha hecho mas de un proceso sobre la misma variable (04_Plantilla Transformacion de datos)
#2. Usar algoritmos como los árboles de decisión o Random Forest que no les afectan las correlaciones entre variables
cor_finales.head(40)
# Out:
#                                         var1  \
# 1743                  room_type_Private room
# 757   calculated_host_listings_count_disc_ds
# 173                      availability_60_yeo
# 349                   host_response_rate_yeo
# 175                      availability_60_yeo
# 1316                  maximum_nights_disc_ds
# 230                      availability_30_yeo
# 670                         accommodates_yeo
# 1760                  room_type_Private room
# 1890               room_type_Entire home/apt
# 1931               room_type_Entire home/apt
# 1719                  room_type_Private room
# 1518                               dryer bed
# 2                       availability_365_yeo
# 3                       availability_365_yeo
# 1853                           stays allowed
# 563         property_type_Entire rental unit
# 1479                                   maker
# 68                                 price_yeo
# 660                         accommodates_yeo
# 4                       availability_365_yeo
# 657                         accommodates_yeo
# 1297                            beds_disc_ds
# 2562                      kitchen essentials
# 3129                            refrigerator
# 1882               room_type_Entire home/apt
# 1451                                   maker
# 2835                                    room
# 100                                price_yeo
# 1711                  room_type_Private room
# 2951                                  basics
# 1469                                   maker
# 3114                            refrigerator
# 524         property_type_Entire rental unit
# 1476                                   maker
# 1162                        bedrooms_disc_ds
# 1536                               dryer bed
# 677                         accommodates_yeo
# 1461                                   maker
# 2430                                clothing
#
#                                                    var2            corr
# 1743                          room_type_Entire home/apt            0.98
# 757   calculated_host_listings_count_entire_homes_di...            0.98
# 173                                 availability_90_yeo            0.97
# 349                               host_response_time_oe            0.95
# 175                                 availability_30_yeo            0.93
# 1316                                 maximum_nights_yeo            0.92
# 230                                 availability_90_yeo            0.87
# 670                                accommodates_disc_ds            0.86
# 1760          property_type_Private room in rental unit            0.85
# 1890                   property_type_Entire rental unit            0.85
# 1931          property_type_Private room in rental unit            0.83
# 1719                   property_type_Entire rental unit            0.83
# 1518                                                bed            0.80
# 2                                   availability_90_yeo            0.78
# 3                                   availability_60_yeo            0.73
# 1853                                            allowed            0.72
# 563           property_type_Private room in rental unit            0.70
# 1479                                       refrigerator            0.68
# 68                                     accommodates_yeo            0.67
# 660                           room_type_Entire home/apt            0.64
# 4                                   availability_30_yeo            0.63
# 657                              room_type_Private room            0.63
# 1297                               accommodates_disc_ds            0.58
# 2562                                       refrigerator            0.58
# 3129                                             basics            0.58
# 1882                                          price_yeo            0.58
# 1451                                          dryer bed            0.57
# 2835                                           clothing            0.56
# 100                                accommodates_disc_ds            0.56
# 1711                                          price_yeo            0.56
# 2951                                 kitchen essentials            0.56
# 1469                                 kitchen essentials            0.56
# 3114                                                bed            0.56
# 524                                    accommodates_yeo            0.55
# 1476                                             basics            0.55
# 1162                                       beds_disc_ds            0.54
# 1536                                       refrigerator            0.54
# 677           property_type_Private room in rental unit            0.54
# 1461                                                bed            0.54
# 2430                                                bed            0.53

# %%
max_correlacion = 0.96
exceso_correlacion = cor_finales.var1.loc[cor_finales['corr']>=max_correlacion].to_list()
exceso_correlacion
# Out:
# ['room_type_Private room',
#  'calculated_host_listings_count_disc_ds',
#  'availability_60_yeo']

# %% [markdown]
# #### 5.1.3. Filtrar variables

# %% [markdown]
# Automáticamente se descartarán las variables que hayan superado la correlación máxima que hayamos definido y se generará una lista con el resto de las variables

# %%
a_eliminar_corr = exceso_correlacion

# %%
x_preseleccionado.drop(columns = a_eliminar_corr, inplace = True)

# %%
x_preseleccionado.columns.to_list()
# Out:
# ['availability_365_yeo',
#  'price_yeo',
#  'availability_90_yeo',
#  'availability_30_yeo',
#  'maximum_nights_yeo',
#  'host_response_rate_yeo',
#  'host_response_time_oe',
#  'neighbourhood_group_Centro',
#  'property_type_Entire rental unit',
#  'neighbourhood_group_Arganzuela',
#  'accommodates_yeo',
#  'wifi kitchen',
#  'neighbourhood_group_Chamberí',
#  'host_is_superhost_oe',
#  'calculated_host_listings_count_entire_homes_disc_ds',
#  'shampoo',
#  'elevator',
#  'instant_bookable_oe',
#  'bedrooms_disc_ds',
#  'neighbourhood_group_Vicálvaro',
#  'beds_disc_ds',
#  'maximum_nights_disc_ds',
#  'air',
#  'maker',
#  'dryer bed',
#  'neighbourhood_group_Ciudad Lineal',
#  'stove',
#  'allowed',
#  'neighbourhood_group_Villaverde',
#  'stays allowed',
#  'room_type_Entire home/apt',
#  'neighbourhood_group_San Blas',
#  'neighbourhood_group_Retiro',
#  'bed',
#  'neighbourhood_group_Chamartín',
#  'dedicated',
#  'host_verifications_oe',
#  'host_has_profile_pic_oe',
#  'neighbourhood_group_Carabanchel',
#  'clothing',
#  'accommodates_disc_ds',
#  'kitchen essentials',
#  'neighbourhood_group_Puente de Vallecas',
#  'neighbourhood_group_Salamanca',
#  'parking',
#  'neighbourhood_group_Latina',
#  'room',
#  'property_type_Private room in rental unit',
#  'basics',
#  'neighbourhood_group_Usera',
#  'freezer',
#  'refrigerator',
#  'neighbourhood_group_Hortaleza',
#  'tv washer']

# %% [markdown]
# ## 6. GUARDAR DATASETS TRAS PRESELECCION DE VARIABLES

# %%
#Definir los nombres de los archivos
nombre_x_preseleccionado = ruta_proyecto + '/02_Datos/03_Trabajo/' + 'x_preseleccionado.pickle'
nombre_y_preseleccionado = ruta_proyecto + '/02_Datos/03_Trabajo/' + 'y_preseleccionado.pickle'

# %%
#Guardar los archivos
x_preseleccionado.to_pickle(nombre_x_preseleccionado)

y_preseleccionado = y.copy()
y_preseleccionado.to_pickle(nombre_y_preseleccionado)

# %%
print("Valores únicos de target:", y_preseleccionado.unique())
print("Conteo de clases:", y_preseleccionado.value_counts())
# Out:
# Valores únicos de target: [1 0]
# Conteo de clases: 1    12554
# 0     5557
# Name: pisos_rentables, dtype: int64

# %%
#Guardar los nombres de las variables finales
nombre_variables_finales = ruta_proyecto + '/05_Resultados/' + 'variables_finales.pickle'

x_preseleccionado.iloc[0].to_pickle(nombre_variables_finales)

# %%
x_preseleccionado.shape
# Out:
# (18111, 54)
